# %%
import pandas as pd  
import numpy as np
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %% [markdown]
# #  Data Preparation

# %%
data = pd.read_csv("USvideos.csv")

# %%
data = data[data.tags !='[none]']

# %%
data.columns.values
# Out:
# array(['video_id', 'title', 'channel_title', 'category_id', 'tags',
#        'views', 'likes', 'dislikes', 'comment_total', 'date'], dtype=object)

# %%
data.shape
# Out:
# (7507, 10)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size = 0.2, random_state=0)

train, val = train_test_split(train, test_size = 0.25, random_state=0)

# %%
train.shape
# Out:
# (4503, 10)

# %%
val.shape
# Out:
# (1502, 10)

# %%
test.shape
# Out:
# (1502, 10)

# %%
def tags_to_phrases( raw_tags ):
    # Function to convert a raw tags to a string of phrases
    # The input is a single string (a raw video tags), and 
    # the output is a single string (a preprocessed video tags)
     
    phrases = raw_tags.lower().split('|')                           
    
    # In Python, searching a set is much faster than searching
    # a list, so convert the stop words to a set
    # to improve execution time this conversion should be done once
    stops = set(stopwords.words("english"))                  
     
    # Remove stop words
    meaningful_words = [w for w in phrases if not w in stops]   
    
    # Join the words back into one string separated by space, 
    # and return the result.
    return( ",".join( meaningful_words ))

# %%
# Initialize an empty list to hold the clean tags
clean_train_tags = []

# %%
for key in train['tags']:
    clean_train_tags.append( tags_to_phrases(key))

# %%
clean_train_tags[1]
# Out:
# 'google lens,chromebook,chrome os,google store,google home,pixel,pixel xl,daydream,vr,ar,android,made by google,october 4th,oct. 4th,oct 4th,launch,new,hardware,phone,phones,devices,device,living room,home,chromecast,accessories,google hardware,tech annoucement,10/4,#madebygoogle,google phone,launch,headset,google,max,mini,clips,pixelbook,buds,google store,project fi,ml,machine learning'

# %%
len(clean_train_tags)
# Out:
# 4503

# %%
clean_val_tags = []

print ("Cleaning and parsing the validation set tags...\n")
for key in val['tags']:
    clean_val_tags.append(tags_to_phrases(key))
# Out:
# Cleaning and parsing the validation set tags...

# %%
clean_test_tags = []

print ("Cleaning and parsing the test set tags...\n")
for key in test['tags']:
    clean_test_tags.append(tags_to_phrases(key))
# Out:
# Cleaning and parsing the test set tags...

# %% [markdown]
# # Data Visualization

# %%
clean_data_tags = []

for key in data['tags']:
    clean_data_tags.append(tags_to_phrases(key))

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


text = ','.join(clean_data_tags)

wordcloud = WordCloud(background_color='white',
                          width=800,
                          height=400
                         ).generate(text)

plt.figure(figsize=(24,14), dpi=1200)
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('cloud.png')

# %% [markdown]
# # Modeling

# %% [markdown]
# ## 1. First attempt: using words in tags to predict 'views'
# Model: random forest + neuralnets

# %%
print ("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 
# Note that CountVectorizer comes with its own options to automatically do preprocessing, tokenization, and stop word removal -- for each of these, instead of specifying "None", we could have used a built-in method or specified our own function to use.

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_tags)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print (vocab)
# Out:
# [u'00', u'00z', u'04', u'08282016ntflxuscan', u'09', u'09t20', u'10', u'100', u'1000', u'10000', u'101', u'1017', u'103', u'1080', u'10m', u'11', u'116', u'12', u'13', u'13th', u'14', u'15', u'17', u'172', u'1727', u'1728', u'1922', u'1987', u'1d', u'2015', u'2016', u'2017', u'2018', u'2049', u'2050', u'20th', u'216', u'217', u'24', u'25', u'25th', u'29', u'2d', u'30', u'360', u'365', u'3am', u'3d', u'40', u'43', u'45m', u'49ers', u'4k', u'4th', u'50', u'500', u'50mm', u'55', u'60', u'64', u'69th', u'73', u'797', u'80s', u'85', u'90s', u'91', u'93', u'98', u'a24', u'a321', u'aaron', u'aarp', u'ab', u'abandoned', u'abc', u'abdul', u'about', u'abrams', u'absurd', u'ac2', u'aca', u'academy', u'acapella', u'acceleration', u'accent', u'access', u'accessories', u'accident', u'account', u'acid', u'acm', u'acne', u'acoustic', u'act', u'acting', u'action', u'active', u'activism', u'actor', u'actors', u'actress', u'ad', u'adam', u'adams', u'addictions', u'adelaine', u'adele', u'adidas', u'adler', u'adorable', u'adriana', u'adult', u'adulting', u'adultolescence', u'adults', u'adventure', u'adventures', u'adventurous', u'advertiser', u'advertising', u'advice', u'aegis', u'aerial', u'afc', u'affairs', u'affleck', u'affordable', u'african', u'after', u'aftershow', u'again', u'age', u'agriculture', u'agt', u'aid', u'aidy', u'aiono', u'air', u'airbus', u'aircraft', u'airlines', u'airman', u'airplane', u'airport', u'aj', u'aje', u'akana', u'al', u'ala', u'alabama', u'aladdin', u'alain', u'alaina', u'alan', u'alaska', u'album', u'alchemist', u'alcohol', u'alcon', u'aldean', u'alec', u'alesso', u'alex', u'alexa', u'alexander', u'alexandria', u'alfa', u'alfie', u'ali', u'alice', u'alicia', u'alien', u'alienist', u'alisha', u'alison', u'alive', u'aljazeera', u'all', u'allegations', u'allen', u'allergy', u'allison', u'ally', u'almost', u'alodia', u'alone', u'aloy', u'alternative', u'alvarez', u'aly', u'am', u'amazing', u'amazon', u'amber', u'ambulance', u'ambush', u'amendment', u'america', u'american', u'americans', u'amore', u'amy', u'an', u'ana', u'analysis', u'anastasia', u'ancient', u'and', u'anderson', u'andre', u'andrea', u'andrew', u'android', u'andy', u'angeles', u'angle', u'angry', u'animal', u'animals', u'animated', u'animation', u'animations', u'anime', u'anitta', u'anker', u'anna', u'annaakana', u'anne', u'annie', u'anniversary', u'annual', u'answer', u'answers', u'antebellum', u'anthem', u'anthony', u'anti', u'anvil', u'anwar', u'anxiety', u'anxious', u'anything', u'anywhere', u'aol', u'apa', u'apartment', u'aperture', u'apocalypse', u'apollo', u'app', u'apple', u'application', u'apply', u'approved', u'apps', u'aquaman', u'ar', u'arabia', u'archery', u'archie', u'architecture', u'are', u'arena', u'argument', u'ari', u'ariana', u'arianna', u'ariel', u'arizona', u'armando', u'armed', u'army', u'arnold', u'aronofsky', u'around', u'arpaio', u'arrow', u'art', u'artem', u'artillery', u'artist', u'artists', u'arts', u'arya', u'as', u'asapscience', u'ashley', u'ashton', u'asian', u'ask', u'asking', u'asmr', u'assault', u'assistant', u'association', u'aston', u'astronaut', u'astronomy', u'at', u'ath', u'athletes', u'atl', u'atlanta', u'atlantic', u'attack', u'attacks', u'attempt', u'attenborough', u'attention', u'attorney', u'atwood', u'atwoods', u'audi', u'audible', u'audience', u'audio', u'auditions', u'augmented', u'aussie', u'austin', u'australia', u'australian', u'auth', u'author', u'auto', u'automatic', u'autotune', u'autumn', u'avengers', u'average', u'avermectin', u'aviation', u'avicii', u'avril', u'aw', u'award', u'awards', u'awareness', u'away', u'awesome', u'awesometacular', u'awkward', u'babies', u'babish', u'baby', u'babysitter', u'bach', u'back', u'backstory', u'bacon', u'bacteria', u'bad', u'bader', u'bag', u'bagel', u'bailey', u'bait', u'bake', u'baked', u'baker', u'bakery', u'baking', u'baldwin', u'ball', u'ballas', u'baller', u'ballinger', u'baltimore', u'ban', u'banana', u'band', u'bang', u'banks', u'bannon', u'bar', u'barbec ...

# %%
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print (count, tag)
# Out:
# (83, u'00')
# (9, u'00z')
# (30, u'04')
# (20, u'08282016ntflxuscan')
# (21, u'09')
# (6, u'09t20')
# (180, u'10')
# (31, u'100')
# (10, u'1000')
# (10, u'10000')
# (16, u'101')
# (5, u'1017')
# (6, u'103')
# (5, u'1080')
# (9, u'10m')
# (37, u'11')
# (8, u'116')
# (53, u'12')
# (17, u'13')
# (8, u'13th')
# (5, u'14')
# (5, u'15')
# (12, u'17')
# (6, u'172')
# (5, u'1727')
# (7, u'1728')
# (6, u'1922')
# (12, u'1987')
# (7, u'1d')
# (5, u'2015')
# (31, u'2016')
# (615, u'2017')
# (26, u'2018')
# (21, u'2049')
# (6, u'2050')
# (9, u'20th')
# (5, u'216')
# (8, u'217')
# (21, u'24')
# (33, u'25')
# (5, u'25th')
# (22, u'29')
# (15, u'2d')
# (20, u'30')
# (27, u'360')
# (8, u'365')
# (6, u'3am')
# (12, u'3d')
# (18, u'40')
# (26, u'43')
# (8, u'45m')
# (9, u'49ers')
# (15, u'4k')
# (19, u'4th')
# (15, u'50')
# (8, u'500')
# (9, u'50mm')
# (5, u'55')
# (9, u'60')
# (10, u'64')
# (7, u'69th')
# (36, u'73')
# (9, u'797')
# (16, u'80s')
# (9, u'85')
# (20, u'90s')
# (8, u'91')
# (9, u'93')
# (6, u'98')
# (28, u'a24')
# (6, u'a321')
# (26, u'aaron')
# (12, u'aarp')
# (8, u'ab')
# (13, u'abandoned')
# (54, u'abc')
# (5, u'abdul')
# (33, u'about')
# (7, u'abrams')
# (6, u'absurd')
# (7, u'ac2')
# (9, u'aca')
# (22, u'academy')
# (11, u'acapella')
# (7, u'acceleration')
# (7, u'accent')
# (14, u'access')
# (22, u'accessories')
# (5, u'accident')
# (13, u'account')
# (20, u'acid')
# (7, u'acm')
# (25, u'acne')
# (21, u'acoustic')
# (19, u'act')
# (7, u'acting')
# (66, u'action')
# (5, u'active')
# (6, u'activism')
# (54, u'actor')
# (19, u'actors')
# (38, u'actress')
# (24, u'ad')
# (158, u'adam')
# (6, u'adams')
# (8, u'addictions')
# (15, u'adelaine')
# (30, u'adele')
# (11, u'adidas')
# (10, u'adler')
# (21, u'adorable')
# (9, u'adriana')
# (12, u'adult')
# (6, u'adulting')
# (13, u'adultolescence')
# (5, u'adults')
# (59, u'adventure')
# (5, u'adventures')
# (10, u'adventurous')
# (10, u'advertiser')
# (6, u'advertising')
# (36, u'advice')
# (6, u'aegis')
# (12, u'aerial')
# (21, u'afc')
# (14, u'affairs')
# (8, u'affleck')
# (16, u'affordable')
# (5, u'african')
# (34, u'after')
# (12, u'aftershow')
# (21, u'again')
# (11, u'age')
# (10, u'agriculture')
# (30, u'agt')
# (7, u'aid')
# (8, u'aidy')
# (6, u'aiono')
# (53, u'air')
# (9, u'airbus')
# (6, u'aircraft')
# (6, u'airlines')
# (8, u'airman')
# (24, u'airplane')
# (6, u'airport')
# (6, u'aj')
# (6, u'aje')
# (8, u'akana')
# (24, u'al')
# (5, u'ala')
# (51, u'alabama')
# (29, u'aladdin')
# (19, u'alain')
# (10, u'alaina')
# (6, u'alan')
# (5, u'alaska')
# (56, u'album')
# (30, u'alchemist')
# (5, u'alcohol')
# (10, u'alcon')
# (8, u'aldean')
# (40, u'alec')
# (54, u'alesso')
# (116, u'alex')
# (6, u'alexa')
# (9, u'alexander')
# (13, u'alexandria')
# (10, u'alfa')
# (8, u'alfie')
# (5, u'ali')
# (15, u'alice')
# (17, u'alicia')
# (16, u'alien')
# (9, u'alienist')
# (16, u'alisha')
# (8, u'alison')
# (13, u'alive')
# (13, u'aljazeera')
# (87, u'all')
# (8, u'allegations')
# (12, u'allen')
# (5, u'allergy')
# (10, u'allison')
# (8, u'ally')
# (13, u'almost')
# (7, u'alodia')
# (25, u'alone')
# (5, u'aloy')
# (84, u'alternative')
# (16, u'alvarez')
# (12, u'aly')
# (20, u'am')
# (117, u'amazing')
# (117, u'amazon')
# (18, u'amber')
# (7, u'ambulance')
# (13, u'ambush')
# (6, u'amendment')
# (113, u'america')
# (109, u'american')
# (8, u'americans')
# (5, u'amore')
# (17, u'amy')
# (38, u'an')
# (13, u'ana')
# (17, u'analysis')
# (6, u'anastasia')
# (8, u'ancient')
# (735, u'and')
# (31, u'anderson')
# (15, u'andre')
# (6, u'andrea')
# (80, u'andrew')
# (33, u'android')
# (51, u'andy')
# (31, u'angeles')
# (15, u'angle')
# (7, u'angry')
# (56, u'animal')
# (63, u'animals')
# (87, u'animated')
# (135, u'animation')
# (9, u'animations')
# (27, u'anime')
# (19, u'anitta')
# (6, u'anker')
# (28, u'anna')
# (7, u'annaakana')
# (10, u'anne')
# (6, u'annie')
# (13, u'anniversary')
# (8, u'annual')
# (12, u'answer')
# (8, u'answers')
# (8, u'antebellum')
# (7, u'anthem')
# (82, u'anthony')
# (14, u'anti')
# (20, u'anvil')
# (53, u'anwar')
# (107, u'anxiety')
# (6, u'anxious')
# (21, u'anything')
# (5, u'anywhere')
# (9, u'aol')
# (38, u'apa')
# (13, u'apartment')
# (6, u'aperture')
# (23, u'apocalypse')
# (7, u'apollo')
# (20, u'app')
# (242, u'apple')
# (10, u'application')
# (10, u'apply')
# (6, u'approved')
# (5, u'apps')
# (7, u'aquaman')
# (9, u'ar')
# (15, u'arabia')
# (10, u'archery')
# (12, u'archie')
# (20, u'architecture')
# (81, u'are')
# (11, u'arena')
# (6, u'argument')
# (10, u'ari')
# (6, u'ariana')
# (6, u'arianna')
# (13, u'ariel')
# (7, u'arizona')
# (5, u'armando')
# (6, u'armed')
# (17, u'army')
# (44, u'arnold')
# (5, u'aronofsky')
# (28, u'around')
# (6, u'arpaio')
# (9, u'arrow')
# (168, u'art')
# (5, u'artem')
# (5, u'artillery')
# (70, u'artist')
# (10, u'artists')
# (30, u'arts')
# (5, u'arya')
# (15, u'as')
# (10, u'asapscience')
# (22, u'ashley')
# (6, u'ashton')
# (26, u'asian')
# (28, u'ask')
# (6, u'asking')
# (18, u'asmr')
# (9, u'assault')
# (24, u'assistant')
# (50, u'association')
# (9, u'aston')
# (18, u'astronaut')
# (11, u'astronomy')
# (78, u'at')
# (20, u'ath')
# (7, u'athletes')
# (5, u'atl')
# (19, u'atlanta')
# (27, u'atlantic')
# (38, u'attack')
# (7, u'attacks')
# (6, u'attempt')
# (5, u'attenborough')
# (18, u'attention')
# (5, u'attorney')
# (49, u'atwood')
# (8, u'atwoods')
# (15, u'audi')
# (10, u'audible')
# (21, u'audience')
# (42, u'audio')
# (38, u'auditions')
# (6, u'augmented')
# (20, u'aussie')
# (36, u'austin')
# (18, u'australia')
# (15, u'australian')
# (20, u'auth')
# (11, u'author')
# (5, u'auto')
# (12, u'automatic')
# (11, u'autotune')
# (36, u'autumn')
# (6, u'avengers')
# (9, u'average')
# (5, u'avermectin')
# (11, u'aviation')
# (8, u'avicii')
# (9, u'avril')
# (6, u'aw')
# (22, u'award')
# (85, u'awards')
# (11, u'awareness')
# (53, u'away')
# (44, u'awesome')
# (13, u'awesometacular')
# (18, u'awkward')
# (16, u'babies')
# (8, u'babish')
# (70, u'baby')
# (5, u'babysitter')
# (5, u'bach')
# (54, u'back')
# (5, u'backstory')
# (8, u'bacon')
# (20, u'bacteria')
# (50, u'bad')
# (6, u'bader')
# (17, u'bag')
# (10, u'bagel')
# (6, u'bailey')
# (9, u'bait')
# (33, u'bake')
# (36, u'baked')
# (15, u'baker')
# (9, u'bakery')
# (61, u'baking')
# (12, u'baldwin')
# (56, u'ball')
# (5, u'ballas')
# (9, u'baller')
# (21, u'ballinger')
# (8, u'baltimore')
# (14, u'ban')
# (9, u'banana')
# (32, u'band')
# (6, u'bang')
# (22, u'banks')
# (7, u'bannon')
# (16, u'bar')
# (16, u'barbecue')
# (10, u'barber')
# (7, u'barcelona')
# (10, u'barefoot')
# (11, u'barely')
# (8, u'barking')
# (11, u'barkley')
# (7, u'barrel')
# (6, u'barry')
# (25, u'bartender')
# (11, u'base')
# (14, u'baseball')
# (7, u'based')
# (17, u'basic')
# (13, u'basics')
# (66, u'basketball')
# (6, u'bath')
# (9, u'bathroom')
# (16, u'batiste')
# (32, u'batman')
# (6, u'battery')
# (23, u'battle')
# (12, u'battlefront')
# (8, u'battlegrounds')
# (40, u'bay')
# (77, u'bbc')
# (8, u'bbq')
# (88, u'be')
# (8, u'bea')
# (24, u'beach')
# (38, u'bear')
# (16, u'bears')
# (9, u'beasts')
# (9, u'beat')
# (24, u'beatbox')
# (35, u'beautiful')
# (468, u'beauty')
# (15, u'bebe')
# (6, u'beck')
# (14, u'beckham')
# (10, u'bed')
# (22, u'bedroom')
# (10, u'bedtime')
# (29, u'bee')
# (11, u'beef')
# (8, u'been')
# (31, u'beer')
# (6, u'beetle')
# (9, u'before')
# (5, u'beginners')
# (8, u'beginning')
# (73, u'behind')
# (6, u'beige')
# (9, u'being')
# (10, u'believer')
# (29, u'bell')
# (116, u'bella')
# (9, u'bellas')
# (81, u'ben')
# (10, u'bend')
# (13, u'benefit')
# (6, u'benefits')
# (30, u'benjamin')
# (8, u'bennett')
# (6, u'berets')
# (5, u'berkeley')
# (6, u'bert')
# (355, u'best')
# (5, u'bestrong')
# (36, u'bet')
# (7, u'beth')
# (9, u'bethany')
# (36, u'better')
# (18, u'between')
# (20, u'beverly')
# (15, u'beyonce')
# (7, u'beyond')
# (15, u'bezos')
# (5, u'bf')
# (19, u'bff')
# (5, u'bhuton')
# (17, u'bianchi')
# (6, u'bible')
# (12, u'bich')
# (6, u'bicyclist')
# (5, u'biden')
# (113, u'big')
# (8, u'bigger')
# (21, u'biggest')
# (5, u'bighit')
# (12, u'bike')
# (27, u'bill')
# (7, u'billboard')
# (12, u'billie')
# (7, u'billy')
# (5, u'binging')
# (6, u'biography')
# (5, u'bioprospecting')
# (5, u'bipolar')
# (12, u'bird')
# (9, u'birdie')
# (18, u'birth')
# (22, u'birthday')
# (13, u'biscuit')
# (12, u'bisping')
# (24, u'bit')
# (10, u'bitch')
# (28, u'bite')
# (8, u'bitten')
# (9, u'bizarre')
# (178, u'black')
# (5, u'blacksmith')
# (62, u'blade')
# (49, u'blake')
# (28, u'blank')
# (5, u'blanket')
# (8, u'blaster')
# (7, u'blasters')
# (28, u'blind')
# (6, u'blindfold')
# (10, u'blindfolded')
# (9, u'blobfish')
# (11, u'block')
# (11, u'blocko')
# (17, u'blog')
# (18, u'blogger')
# (21, u'blood')
# (22, u'blooper')
# (25, u'bloopers')
# (35, u'blossom')
# (8, u'blow')
# (5, u'blu')
# (62, u'blue')
# (12, u'blur')
# (13, u'bmg')
# (18, u'bmw')
# (22, u'bmx')
# (9, u'board')
# (9, u'boat')
# (32, u'bob')
# (15, u'bobby')
# (5, u'bobi')
# (30, u'bodak')
# (37, u'body')
# (6, u'boeing')
# (10, u'bold')
# (8, u'boldly')
# (16, u'bomb')
# (6, u'bombs')
# (12, u'bon')
# (9, u'bone')
# (7, u'bones')
# (21, u'boogie')
# (5, u'boogie2988')
# (79, u'book')
# (36, u'books')
# (5, u'bookshelf')
# (7, u'boone')
# (26, u'boost')
# (5, u'boot')
# (5, u'boots')
# (6, u'borders')
# (5, u'born')
# (5, u'boss')
# (10, u'boston')
# (6, u'bostrom')
# (26, u'bottle')
# (28, u'bottoms')
# (20, u'botton')
# (6, u'bourgeois')
# (5, u'boutique')
# (9, u'bow')
# (15, u'bowflex')
# (5, u'bowling')
# (16, u'box')
# (8, u'boxing')
# (49, u'boy')
# (6, u'boyband')
# (16, u'boyd')
# (6, u'boyega')
# (79, u'boyfriend')
# (32, u'boys')
# (5, u'bra')
# (12, u'brad')
# (6, u'bradley')
# (6, u'braga')
# (29, u'brain')
# (30, u'brand')
# (5, u'brandon')
# (7, u'braun')
# (18, u'brave')
# (52, u'bravo')
# (11, u'braxton')
# (11, u'bread')
# (12, u'break')
# (12, u'breakdown')
# (30, u'breakfast')
# (83, u'breaking')
# (5, u'breaks')
# (8, u'breakup')
# (15, u'breast')
# (8, u'breath')
# (11, u'breed')
# (12, u'bregoli')
# (10, u'bresnik')
# (24, u'brett')
# (64, u'brexit')
# (24, u'brian')
# (9, u'bridal')
# (8, u'bride')
# (5, u'bridge')
# (7, u'brie')
# (5, u'brief')
# (6, u'briefing')
# (27, u'brien')
# (11, u'bring')
# (14, u'brit')
# (9, u'britain')
# (18, u'british')
# (8, u'britt')
# (12, u'brittany')
# (8, u'brittney')
# (6, u'bro')
# (14, u'broadband')
# (12, u'broadcasting')
# (8, u'broken')
# (7, u'bronx')
# (15, u'brooke')
# (11, u'brooklyn')
# (6, u'brooks')
# (56, u'bros')
# (32, u'brother')
# (12, u'brotherhood')
# (62, u'brothers')
# (79, u'brown')
# (12, u'brownie')
# (11, u'brownies')
# (13, u'bruce')
# (9, u'brunch')
# (16, u'bruno')
# (11, u'brush')
# (8, u'brushes')
# (20, u'bryan')
# (8, u'bryant')
# (6, u'bryson')
# (12, u'bts')
# (13, u'bubble')
# (10, u'budapest')
# (27, u'budget')
# (6, u'buds')
# (6, u'buffet')
# (7, u'buffing')
# (6, u'bugg')
# (12, u'bugs')
# (24, u'build')
# (8, u'builder')
# (21, u'building')
# (7, u'builds')
# (38, u'bull')
# (12, u'bullied')
# (10, u'bully')
# (13, u'bullying')
# (35, u'bump')
# (7, u'bumpstock')
# (15, u'bunny')
# (8, u'buns')
# (82, u'burger')
# (15, u'burgers')
# (9, u'burke')
# (5, u'burn')
# (13, u'burning')
# (5, u'bursting')
# (45, u'business')
# (6, u'but')
# (25, u'butter')
# (30, u'buttercream')
# (6, u'buttercup')
# (23, u'button')
# (35, u'buy')
# (13, u'buying')
# (8, u'buys')
# (209, u'buzzfeed')
# (14, u'buzzfeedblue')
# (27, u'buzzfeedvideo')
# (104, u'by')
# (32, u'bybel')
# (9, u'bye')
# (10, u'bypass')
# (8, u'byu')
# (8, u'byutelevision')
# (11, u'byutv')
# (19, u'cabello')
# (5, u'cabinet')
# (6, u'cadets')
# (9, u'caitlyn')
# (240, u'cake')
# (44, u'cakes')
# (8, u'caleb')
# (30, u'california')
# (30, u'call')
# (5, u'calming')
# (6, u'calories')
# (11, u'cam')
# (81, u'camera')
# (16, u'cameraguy')
# (20, u'cameras')
# (26, u'cameron')
# (24, u'camila')
# (7, u'camo')
# (22, u'camp')
# (7, u'campaign')
# (16, u'campus')
# (24, u'can')
# (15, u'canada')
# (5, u'canadian')
# (25, u'cancer')
# (14, u'candace')
# (7, u'candles')
# (48, u'candy')
# (71, u'canelo')
# (13, u'cannes')
# (5, u'canon')
# (5, u'canyon')
# (12, u'caoimhe')
# (24, u'capitol')
# (6, u'cappella')
# (9, u'captain')
# (6, u'captioned')
# (14, u'capture')
# (98, u'car')
# (9, u'cara')
# (10, u'caramorello')
# (8, u'card')
# (10, u'cardboard')
# (29, u'cardi')
# (6, u'cardinals')
# (6, u'cardona')
# (6, u'cards')
# (47, u'care')
# (12, u'career')
# (16, u'carey')
# (9, u'caribbean')
# (5, u'carice')
# (9, u'carl')
# (15, u'carli')
# (21, u'carlibel')
# (12, u'carlibel55')
# (12, u'carlibybel')
# (5, u'carlibybelxmissguided')
# (61, u'carlin')
# (36, u'carlos')
# (7, u'carly')
# (38, u'carmelo')
# (13, u'carmen')
# (11, u'carol')
# (14, u'carolina')
# (9, u'carpenter')
# (48, u'carpet')
# (7, u'carpets')
# (24, u'carpool')
# (5, u'carr')
# (9, u'carrey')
# (7, u'carrie')
# (5, u'carrot')
# (8, u'carry')
# (20, u'cars')
# (13, u'carson')
# (22, u'carter')
# (66, u'cartoon')
# (27, u'cartoons')
# (6, u'carve')
# (10, u'carving')
# (9, u'cary')
# (5, u'cases')
# (35, u'casey')
# (6, u'cash')
# (14, u'casino')
# (12, u'cassidy')
# (38, u'cassini')
# (12, u'cassoulet')
# (41, u'cast')
# (8, u'castle')
# (233, u'cat')
# (8, u'catalan')
# (23, u'catalonia')
# (26, u'catch')
# (6, u'category')
# (70, u'cats')
# (5, u'catt')
# (9, u'causes')
# (18, u'cavaliers')
# (10, u'cave')
# (7, u'caviar')
# (8, u'cavs')
# (72, u'cbs')
# (10, u'cbsn')
# (14, u'cc')
# (5, u'cctv')
# (5, u'cctvnews')
# (6, u'cedar')
# (109, u'celeb')
# (93, u'celebrities')
# (268, u'celebrity')
# (6, u'celebs')
# (8, u'cell')
# (6, u'cello')
# (6, u'cellos')
# (7, u'cellular')
# (11, u'celtics')
# (5, u'cena')
# (11, u'center')
# (26, u'central')
# (12, u'century')
# (5, u'cersei')
# (6, u'cesaro')
# (6, u'cfb')
# (8, u'cgtn')
# (31, u'ch')
# (12, u'chae')
# (24, u'chain')
# (8, u'chair')
# (259, u'challenge')
# (33, u'challenges')
# (16, u'champion')
# (5, u'champions')
# (28, u'championship')
# (21, u'championships')
# (34, u'chan')
# (7, u'chance')
# (32, u'change')
# (21, u'changes')
# (116, u'channel')
# (5, u'chappelle')
# (12, u'chapter')
# (8, u'character')
# (19, u'characters')
# (8, u'charge')
# (23, u'charger')
# (6, u'chargers')
# (8, u'charging')
# (19, u'charity')
# (5, u'charlamagne')
# (7, u'charlatans')
# (35, u'charles')
# (70, u'charlie')
# (22, u'chase')
# (39, u'chasing')
# (6, u'chastain')
# (48, u'chat')
# (9, u'chatty')
# (5, u'chc')
# (121, u'cheap')
# (15, u'cheat')
# (8, u'cheating')
# (33, u'cheese')
# (14, u'cheeseburger')
# (91, u'chef')
# (26, u'chelsea')
# (5, u'chemistry')
# (6, u'chemo')
# (8, u'chemotherapy')
# (33, u'cheryl')
# (15, u'cherylblossom')
# (8, u'chesney')
# (6, u'chevy')
# (8, u'chh')
# (9, u'chi')
# (19, u'chicago')
# (86, u'chicken')
# (12, u'chiefs')
# (5, u'chigvintsev')
# (10, u'child')
# (13, u'childhood')
# (38, u'children')
# (5, u'chilling')
# (48, u'china')
# (5, u'chinanews')
# (44, u'chinese')
# (24, u'chit')
# (10, u'chloe')
# (10, u'chloemorello')
# (102, u'chocolate')
# (9, u'choice')
# (9, u'choir')
# (5, u'chokeslam')
# (6, u'chop')
# (6, u'choreography')
# (109, u'chris')
# (16, u'chrissy')
# (22, u'christen')
# (36, u'christian')
# (12, u'christie')
# (9, u'christina')
# (41, u'christmas')
# (14, u'christopher')
# (7, u'chrome')
# (20, u'chromebook')
# (6, u'chronicles')
# (5, u'chuck')
# (6, u'chucky')
# (9, u'church')
# (24, u'cindy')
# (7, u'cinefix')
# (22, u'cinema')
# (12, u'cinemasins')
# (10, u'circle')
# (10, u'circuit')
# (10, u'circus')
# (88, u'city')
# (18, u'civil')
# (12, u'clancy')
# (17, u'clans')
# (6, u'clara')
# (19, u'clark')
# (10, u'clarke')
# (14, u'clarkson')
# (18, u'clash')
# (29, u'class')
# (5, u'classes')
# (50, u'classic')
# (6, u'classical')
# (6, u'classroom')
# (5, u'clean')
# (10, u'clear')
# (5, u'cleary')
# (20, u'clemson')
# (7, u'cleveland')
# (10, u'clevver')
# (8, u'click')
# (15, u'clickbait')
# (8, u'clickwithcompassion')
# (10, u'climate')
# (22, u'clinton')
# (66, u'clip')
# (67, u'clips')
# (6, u'clique')
# (8, u'clocks')
# (8, u'clockwork')
# (7, u'closed')
# (22, u'closer')
# (10, u'closet')
# (58, u'clothes')
# (46, u'clothing')
# (6, u'cloud')
# (5, u'clouds')
# (61, u'clown')
# (24, u'clowns')
# (30, u'club')
# (6, u'clublife')
# (8, u'cma')
# (6, u'cmas')
# (15, u'cmt')
# (15, u'cnn')
# (15, u'coach')
# (28, u'coast')
# (5, u'coat')
# (5, u'coating')
# (20, u'cocktail')
# (17, u'coco')
# (23, u'cod')
# (7, u'code')
# (13, u'cody')
# (18, u'coffee')
# (26, u'cohen')
# (8, u'coke')
# (102, u'colbert')
# (13, u'cold')
# (11, u'cole')
# (19, u'coleman')
# (46, u'colin')
# (29, u'collab')
# (18, u'collaboration')
# (30, u'collection')
# (5, u'collective')
# (21, u'colleen')
# (25, u'college')
# (23, u'collegehumor')
# (10, u'collider')
# (17, u'collins')
# (10, u'collision')
# (10, u'colony')
# (23, u'color')
# (17, u'colors')
# (7, u'colour')
# (54, u'columbia')
# (106, u'com')
# (7, u'come')
# (96, u'comedian')
# (28, u'comedians')
# (43, u'comedic')
# (582, u'comedy')
# (8, u'comfort')
# (10, u'comfortable')
# (51, u'comic')
# (55, u'comics')
# (7, u'comin')
# (32, u'coming')
# (10, u'commentary')
# (31, u'commercial')
# (7, u'commercials')
# (15, u'common')
# (8, u'community')
# (10, u'commuter')
# (8, u'como')
# (16, u'companies')
# (33, u'company')
# (16, u'compares')
# (30, u'comparison')
# (25, u'competition')
# (9, u'competitive')
# (24, u'compilation')
# (6, u'complete')
# (74, u'complex')
# (8, u'complicated')
# (34, u'computer')
# (26, u'con')
# (23, u'conan')
# (7, u'concealer')
# (37, u'concert')
# (6, u'confederacy')
# (8, u'confederate')
# (46, u'conference')
# (6, u'confidence')
# (20, u'congress')
# (9, u'connor')
# (16, u'conover')
# (10, u'conservative')
# (7, u'console')
# (6, u'conspiracy')
# (7, u'construction')
# (14, u'consumer')
# (6, u'contestants')
# (26, u'contour')
# (23, u'control')
# (5, u'controller')
# (7, u'conversation')
# (7, u'conway')
# (135, u'cook')
# (15, u'cookie')
# (6, u'cookies')
# (193, u'cooking')
# (36, u'cool')
# (12, u'cooper')
# (5, u'cope')
# (7, u'cops')
# (8, u'copyright')
# (87, u'corden')
# (10, u'corey')
# (16, u'corinne')
# (5, u'cork')
# (14, u'corker')
# (6, u'cormier')
# (14, u'corn')
# (10, u'cornbread')
# (7, u'corporate')
# (5, u'corporation')
# (15, u'corporations')
# (5, u'correction')
# (102, u'cosmetics')
# (6, u'cosmic')
# (11, u'cosplay')
# (5, u'cost')
# (8, u'coster')
# (114, u'costume')
# (107, u'costumes')
# (5, u'couch')
# (10, u'could')
# (10, u'countries')
# (102, u'country')
# (8, u'county')
# (46, u'couple')
# (23, u'couples')
# (9, u'course')
# (8, u'courtney')
# (5, u'covenant')
# (125, u'cover')
# (25, u'coverage')
# (8, u'coverboy')
# (27, u'covergirl')
# (8, u'coverproof')
# (11, u'covers')
# (6, u'covet')
# (6, u'covey')
# (18, u'cowell')
# (20, u'coyote')
# (5, u'cozart')
# (8, u'cq')
# (10, u'cquartz')
# (5, u'crab')
# (45, u'cracked')
# (27, u'craft')
# (5, u'crafting')
# (8, u'cranston')
# (8, u'crappy')
# (26, u'crash')
# (21, u'crawford')
# (78, u'crazy')
# (35, u'cream')
# (17, u'creation')
# (8, u'creative')
# (6, u'creativity')
# (6, u'creature')
# (11, u'creatures')
# (5, u'creeped')
# (32, u'creepy')
# (29, u'crime')
# (5, u'criminal')
# (5, u'criss')
# (30, u'crissy')
# (5, u'cristiano')
# (8, u'cristine')
# (7, u'critic')
# (6, u'crossover')
# (7, u'cruise')
# (11, u'crumbs')
# (25, u'crush')
# (11, u'cruz')
# (18, u'cry')
# (7, u'crying')
# (14, u'crystal')
# (13, u'cuba')
# (5, u'cube')
# (7, u'cuisine')
# (7, u'cult')
# (84, u'culture')
# (6, u'cunningham')
# (11, u'cuomo')
# (46, u'cup')
# (31, u'cupcake')
# (82, u'cupcakes')
# (5, u'curb')
# (11, u'cure')
# (39, u'current')
# (11, u'curriculum')
# (17, u'curry')
# (5, u'curtis')
# (5, u'custom')
# (27, u'cut')
# (169, u'cute')
# (5, u'cuts')
# (9, u'cutter')
# (6, u'cutting')
# (10, u'cw')
# (5, u'cwierz')
# (8, u'cy')
# (32, u'cyanide')
# (5, u'cyborg')
# (10, u'cyclist')
# (8, u'cyclopamine')
# (8, u'cyclops')
# (8, u'cypher')
# (53, u'cyrus')
# (10, u'czar')
# (8, u'd3sports')
# (13, u'da')
# (15, u'dab')
# (48, u'dad')
# (15, u'daddy')
# (10, u'daenerys')
# (11, u'dagger')
# (124, u'daily')
# (17, u'dailygrace')
# (14, u'dairy')
# (55, u'daisy')
# (11, u'dakota')
# (14, u'daley')
# (23, u'dallas')
# (7, u'daly')
# (14, u'damage')
# (5, u'damn')
# (5, u'damon')
# (54, u'dan')
# (88, u'dance')
# (69, u'dancing')
# (34, u'dangerous')
# (44, u'daniel')
# (20, u'danielle')
# (12, u'danny')
# (8, u'dare')
# (9, u'darius')
# (47, u'dark')
# (13, u'darkest')
# (6, u'darren')
# (6, u'dash')
# (10, u'data')
# (57, u'date')
# (9, u'dates')
# (46, u'dating')
# (24, u'dave')
# (109, u'david')
# (6, u'davidparody')
# (19, u'davis')
# (5, u'dawk')
# (5, u'dawkins')
# (5, u'dawkinsmta')
# (30, u'dawn')
# (19, u'dawson')
# (117, u'day')
# (13, u'daydream')
# (19, u'days')
# (7, u'daytime')
# (50, u'dc')
# (61, u'de')
# (5, u'dea')
# (21, u'dead')
# (10, u'deadly')
# (7, u'deaf')
# (14, u'deal')
# (8, u'deals')
# (20, u'dean')
# (8, u'dear')
# (52, u'death')
# (19, u'debra')
# (5, u'debut')
# (6, u'decal')
# (5, u'decimal')
# (28, u'decor')
# (14, u'decorate')
# (17, u'decorating')
# (10, u'decoration')
# (11, u'deep')
# (6, u'deer')
# (7, u'def')
# (6, u'defect')
# (35, u'defense')
# (6, u'definition')
# (24, u'defranco')
# (47, u'degeneres')
# (12, u'degrasse')
# (12, u'del')
# (7, u'delicious')
# (26, u'deluxe')
# (65, u'demi')
# (19, u'demo')
# (5, u'demogorgon')
# (6, u'demons')
# (5, u'denim')
# (13, u'denmark')
# (8, u'denzel')
# (5, u'depeche')
# (15, u'depression')
# (17, u'derek')
# (6, u'derulo')
# (6, u'descendants')
# (11, u'desert')
# (18, u'deserve')
# (26, u'desi')
# (72, u'design')
# (6, u'desk')
# (8, u'despacito')
# (42, u'dessert')
# (7, u'desserts')
# (15, u'destruction')
# (19, u'details')
# (7, u'development')
# (9, u'device')
# (5, u'devil')
# (6, u'devin')
# (8, u'dhia')
# (15, u'diamond')
# (8, u'dice')
# (20, u'did')
# (19, u'didn')
# (14, u'die')
# (6, u'died')
# (6, u'diedrich')
# (6, u'diego')
# (27, u'diet')
# (5, u'diets')
# (6, u'dietschy')
# (13, u'difference')
# (9, u'different')
# (33, u'digital')
# (6, u'dillon')
# (6, u'dining')
# (17, u'dinner')
# (10, u'direction')
# (6, u'director')
# (30, u'disaster')
# (7, u'disasters')
# (13, u'disco')
# (9, u'discount')
# (12, u'discovery')
# (14, u'disease')
# (11, u'dish')
# (7, u'disick')
# (166, u'disney')
# (14, u'disorder')
# (10, u'diss')
# (10, u'district')
# (7, u'dive')
# (8, u'diver')
# (12, u'diving')
# (20, u'division')
# (315, u'diy')
# (52, u'dj')
# (17, u'dji')
# (5, u'dkirk')
# (23, u'dna')
# (98, u'do')
# (15, u'dobrik')
# (7, u'docs')
# (9, u'doctor')
# (18, u'doctors')
# (53, u'documentary')
# (6, u'dodge')
# (7, u'dodie')
# (14, u'dodo')
# (45, u'does')
# (228, u'dog')
# (113, u'dogs')
# (11, u'doilies')
# (7, u'doing')
# (21, u'dolan')
# (6, u'doll')
# (24, u'dollar')
# (10, u'dollars')
# (7, u'dolls')
# (6, u'dominic')
# (9, u'dominican')
# (22, u'dominique')
# (39, u'domino')
# (26, u'dominoes')
# (7, u'dominos')
# (53, u'domo')
# (10, u'domonic')
# (64, u'don')
# (121, u'donald')
# (5, u'donation')
# (18, u'donkey')
# (29, u'dont')
# (29, u'donut')
# (41, u'donuts')
# (7, u'door')
# (12, u'double')
# (11, u'doug')
# (6, u'douglas')
# (41, u'down')
# (8, u'downtown')
# (19, u'dp')
# (38, u'dr')
# (35, u'drag')
# (6, u'dragic')
# (8, u'dragon')
# (30, u'dragons')
# (9, u'drake')
# (99, u'drama')
# (16, u'draw')
# (6, u'dream')
# (8, u'dreams')
# (28, u'dress')
# (9, u'dressed')
# (9, u'drift')
# (12, u'drink')
# (7, u'drivable')
# (39, u'drive')
# (10, u'driver')
# (11, u'drivers')
# (22, u'driving')
# (56, u'drone')
# (8, u'drones')
# (29, u'drop')
# (23, u'drops')
# (8, u'drug')
# (15, u'drugs')
# (48, u'drugstore')
# (9, u'drunk')
# (9, u'dry')
# (42, u'dt')
# (6, u'dub')
# (11, u'duck')
# (44, u'dude')
# (7, u'dumbledore')
# (30, u'dunkin')
# (12, u'dunn')
# (12, u'durability')
# (8, u'duran')
# (18, u'durant')
# (23, u'dusk')
# (16, u'dustin')
# (30, u'dwayne')
# (33, u'dwts')
# (15, u'dwyane')
# (9, u'dxo')
# (15, u'dxomark')
# (12, u'dylan')
# (6, u'dynasty')
# (7, u'e30')
# (97, u'earth')
# (38, u'earthquake')
# (22, u'east')
# (159, u'easy')
# (55, u'eat')
# (6, u'eater')
# (80, u'eating')
# (18, u'eats')
# (42, u'ebay')
# (11, u'ebe')
# (11, u'ebro')
# (24, u'echosmith')
# (10, u'economy')
# (56, u'ed')
# (6, u'eden')
# (14, u'edge')
# (6, u'edgy')
# (10, u'edible')
# (47, u'edition')
# (6, u'editor')
# (29, u'edm')
# (94, u'education')
# (18, u'educational')
# (6, u'edward')
# (15, u'effect')
# (27, u'effects')
# (41, u'efron')
# (8, u'egg')
# (12, u'eiffel')
# (8, u'eilish')
# (7, u'einstein')
# (5, u'eire')
# (5, u'eisner')
# (5, u'elba')
# (15, u'elders')
# (16, u'eldredge')
# (6, u'eldridge')
# (17, u'election')
# (7, u'elections')
# (39, u'electric')
# (5, u'electro')
# (5, u'electromagnetic')
# (32, u'electronic')
# (7, u'electronics')
# (8, u'elevation')
# (6, u'eleven')
# (6, u'eli')
# (20, u'elizabeth')
# (14, u'elle')
# (162, u'ellen')
# (23, u'ellentube')
# (6, u'ellington')
# (20, u'ellis')
# (8, u'elon')
# (11, u'elsa')
# (19, u'else')
# (9, u'elvis')
# (6, u'elwes')
# (5, u'embarrassing')
# (6, u'emergency')
# (5, u'emi')
# (8, u'emilia')
# (15, u'emily')
# (33, u'eminem')
# (13, u'emma')
# (14, u'emmalyn')
# (73, u'emmy')
# (60, u'emmys')
# (6, u'emo')
# (60, u'emoji')
# (8, u'empire')
# (5, u'employees')
# (23, u'empowerment')
# (10, u'empty')
# (42, u'en')
# (35, u'end')
# (20, u'ending')
# (31, u'energy')
# (5, u'engadget')
# (13, u'engine')
# (31, u'engineering')
# (12, u'england')
# (27, u'english')
# (7, u'englishman')
# (8, u'enormous')
# (186, u'entertainment')
# (5, u'entitlement')
# (11, u'enuff')
# (20, u'environment')
# (11, u'environmental')
# (5, u'envy')
# (16, u'ep')
# (42, u'epic')
# (128, u'episode')
# (55, u'episodes')
# (6, u'epl')
# (10, u'eps')
# (14, u'equifax')
# (8, u'equipment')
# (18, u'era')
# (29, u'eric')
# (5, u'escobar')
# (5, u'escort')
# (8, u'esl')
# (62, u'espn')
# (8, u'essay')
# (9, u'essential')
# (7, u'essentials')
# (5, u'estados')
# (10, u'estee')
# (16, u'et')
# (11, u'ethan')
# (5, u'ethnic')
# (6, u'etihad')
# (9, u'etonline')
# (13, u'eu')
# (8, u'euroleague')
# (14, u'europe')
# (9, u'european')
# (5, u'ev')
# (13, u'eva')
# (5, u'evacuation')
# (5, u'evacuations')
# (7, u'evan')
# (46, u'evans')
# (7, u'eve')
# (6, u'evening')
# (19, u'event')
# (35, u'events')
# (133, u'ever')
# (5, u'everhart')
# (82, u'every')
# (11, u'everybody')
# (38, u'everyday')
# (18, u'everyone')
# (86, u'everything')
# (8, u'evolution')
# (10, u'evolve')
# (12, u'eww')
# (14, u'ex')
# (11, u'excited')
# (11, u'exclusive')
# (9, u'exercise')
# (10, u'exist')
# (8, u'exlposm')
# (77, u'expensive')
# (33, u'experience')
# (30, u'experiment')
# (5, u'expert')
# (18, u'explain')
# (32, u'explained')
# (5, u'explains')
# (5, u'explode')
# (10, u'exploration')
# (9, u'explosion')
# (32, u'explosm')
# (8, u'explosmentertainment')
# (9, u'express')
# (7, u'extended')
# (6, u'extinct')
# (6, u'extra')
# (16, u'extreme')
# (41, u'eye')
# (6, u'eyebrow')
# (8, u'eyebrows')
# (10, u'eyelashes')
# (10, u'eyeliner')
# (41, u'eyes')
# (17, u'eyeshadow')
# (8, u'eyeshadows')
# (9, u'ezra')
# (70, u'face')
# (43, u'facebook')
# (8, u'faced')
# (6, u'facepaint')
# (6, u'factor')
# (13, u'factory')
# (46, u'facts')
# (76, u'fail')
# (32, u'fails')
# (35, u'fair')
# (14, u'faith')
# (12, u'fajita')
# (33, u'fake')
# (6, u'falcone')
# (197, u'fall')
# (8, u'fallen')
# (6, u'falling')
# (54, u'fallon')
# (12, u'fallout')
# (9, u'falls')
# (14, u'false')
# (28, u'fame')
# (17, u'families')
# (213, u'family')
# (101, u'famous')
# (82, u'fan')
# (9, u'fancy')
# (12, u'fanning')
# (36, u'fans')
# (13, u'fantastic')
# (16, u'fantasy')
# (8, u'far')
# (17, u'farm')
# (8, u'farming')
# (13, u'farrell')
# (241, u'fashion')
# (109, u'fast')
# (10, u'fastest')
# (9, u'fat')
# (53, u'father')
# (7, u'fatherhood')
# (18, u'faves')
# (12, u'favorite')
# (39, u'favorites')
# (5, u'favs')
# (7, u'fbe')
# (8, u'fbi')
# (17, u'fcute')
# (6, u'fear')
# (21, u'feast')
# (33, u'feat')
# (19, u'feature')
# (10, u'features')
# (7, u'federation')
# (6, u'feed')
# (8, u'feeding')
# (28, u'feel')
# (13, u'feeling')
# (5, u'feels')
# (41, u'female')
# (5, u'feminism')
# (188, u'fenty')
# (13, u'fergie')
# (11, u'ferrari')
# (48, u'festival')
# (7, u'feud')
# (5, u'fgl')
# (10, u'fi')
# (9, u'fiction')
# (48, u'fidget')
# (24, u'field')
# (11, u'fields')
# (15, u'fifth')
# (12, u'fifty')
# (76, u'fight')
# (17, u'fighting')
# (13, u'figures')
# (6, u'file')
# (14, u'files')
# (7, u'filipina')
# (8, u'filipino')
# (254, u'film')
# (14, u'filmmaking')
# (35, u'films')
# (6, u'filter')
# (15, u'final')
# (7, u'finale')
# (14, u'finals')
# (10, u'finance')
# (9, u'financial')
# (14, u'find')
# (8, u'finding')
# (23, u'fine')
# (7, u'finebros')
# (5, u'finest')
# (9, u'finger')
# (6, u'fingers')
# (5, u'finish')
# (8, u'fink')
# (8, u'finn')
# (8, u'fiona')
# (78, u'fire')
# (5, u'fires')
# (286, u'first')
# (21, u'firstwefeast')
# (25, u'fish')
# (24, u'fisher')
# (8, u'fishing')
# (7, u'fit')
# (34, u'fitness')
# (9, u'fitz')
# (8, u'flag')
# (8, u'flags')
# (6, u'flame')
# (5, u'flannel')
# (20, u'flash')
# (9, u'flavors')
# (13, u'flawless')
# (10, u'fletcher')
# (8, u'fleur')
# (15, u'flex')
# (16, u'flight')
# (26, u'flip')
# (8, u'flipbook')
# (7, u'floating')
# (10, u'flooding')
# (9, u'floor')
# (5, u'florence')
# (78, u'florida')
# (24, u'floss')
# (12, u'floyd')
# (15, u'fly')
# (14, u'flying')
# (6, u'fma')
# (6, u'focus')
# (6, u'fogelmanis')
# (5, u'folk')
# (16, u'follow')
# (15, u'fonda')
# (8, u'fondant')
# (5, u'fonsi')
# (563, u'food')
# (15, u'foodie')
# (9, u'foodies')
# (32, u'foods')
# (7, u'foodwishes')
# (27, u'foot')
# (23, u'footage')
# (187, u'football')
# (213, u'for')
# (29, u'force')
# (57, u'ford')
# (10, u'foreign')
# (5, u'foreigner')
# (6, u'forensic')
# (5, u'forster')
# (17, u'fort')
# (43, u'found')
# (102, u'foundation')
# (10, u'foundations')
# (9, u'fountain')
# (8, u'fouseytube')
# (123, u'fox')
# (5, u'foxtrot')
# (15, u'fpv')
# (6, u'frame')
# (9, u'france')
# (5, u'francis')
# (18, u'francisco')
# (12, u'franco')
# (14, u'frank')
# (7, u'frankenstein')
# (18, u'frankie')
# (6, u'franklin')
# (8, u'franta')
# (5, u'freakout')
# (12, u'frederator')
# (74, u'free')
# (12, u'freedom')
# (35, u'freestyle')
# (49, u'french')
# (9, u'fresh')
# (20, u'friday')
# (14, u'fried')
# (28, u'friend')
# (136, u'friendly')
# (50, u'friends')
# (8, u'fries')
# (6, u'frmheadtotoe')
# (26, u'frog')
# (15, u'frogfish')
# (86, u'from')
# (6, u'fromheadtotoe')
# (35, u'front')
# (19, u'frontal')
# (13, u'frosting')
# (10, u'frozen')
# (21, u'fruit')
# (18, u'fs1')
# (65, u'ft')
# (33, u'fudge')
# (8, u'fuel')
# (5, u'fueled')
# (174, u'full')
# (10, u'fuller')
# (24, u'fullmetal')
# (110, u'fun')
# (5, u'function')
# (7, u'fund')
# (5, u'fungi')
# (15, u'funk')
# (21, u'funniest')
# (812, u'funny')
# (14, u'furious')
# (11, u'furniture')
# (7, u'furs')
# (11, u'furze')
# (9, u'futbol')
# (66, u'future')
# (5, u'fvid')
# (21, u'fwf')
# (14, u'fx')
# (8, u'f\xfcr')
# (23, u'gabbie')
# (12, u'gabi')
# (6, u'gabriel')
# (8, u'gaby')
# (16, u'gadget')
# (120, u'gadgets')
# (36, u'gadot')
# (11, u'gag')
# (13, u'gaga')
# (36, u'gal')
# (57, u'galaxy')
# (6, u'gallagher')
# (199, u'game')
# (15, u'gameplay')
# (124, u'games')
# (53, u'gaming')
# (11, u'gamp')
# (17, u'gampp')
# (6, u'gang')
# (8, u'gangster')
# (8, u'garage')
# (5, u'garcia')
# (8, u'garden')
# (11, u'gardner')
# (24, u'gary')
# (8, u'garyvee')
# (22, u'gas')
# (10, u'gastric')
# (11, u'gaten')
# (8, u'gathering')
# (7, u'gatsby')
# (10, u'gaurd')
# (7, u'gavin')
# (35, u'gay')
# (7, u'gbs')
# (13, u'gear')
# (15, u'gender')
# (6, u'general')
# (9, u'generation')
# (8, u'genes')
# (9, u'genetic')
# (6, u'genie')
# (6, u'genius')
# (16, u'gennady')
# (30, u'genre')
# (9, u'geo')
# (11, u'geode')
# (33, u'geography')
# (22, u'george')
# (22, u'georgia')
# (128, u'get')
# (11, u'getting')
# (8, u'getty')
# (31, u'ggg')
# (21, u'ghost')
# (52, u'giant')
# (15, u'giants')
# (6, u'gibbler')
# (20, u'gifts')
# (9, u'gigi')
# (14, u'gill')
# (8, u'gingin')
# (6, u'giraffe')
# (97, u'girl')
# (69, u'girlfriend')
# (76, u'girls')
# (6, u'giulia')
# (9, u'giving')
# (86, u'glam')
# (9, u'glass')
# (12, u'glee')
# (17, u'glitter')
# (6, u'global')
# (7, u'glow')
# (6, u'glowy')
# (17, u'gma')
# (108, u'gmm')
# (49, u'go')
# (11, u'goal')
# (18, u'goals')
# (10, u'god')
# (14, u'goes')
# (6, u'goggins')
# (7, u'goin')
# (26, u'going')
# (6, u'gokhan')
# (40, u'gold')
# (13, u'goldberg')
# (41, u'golden')
# (10, u'goldman')
# (44, u'golovkin')
# (12, u'gomez')
# (8, u'gone')
# (171, u'good')
# (30, u'goodbyes')
# (244, u'google')
# (16, u'gopro')
# (106, u'gordon')
# (8, u'gorgeous')
# (40, u'gosling')
# (52, u'gossip')
# (107, u'got')
# (17, u'got7')
# (10, u'goth')
# (12, u'gotti')
# (7, u'gotye')
# (14, u'government')
# (20, u'gr')
# (130, u'grace')
# (17, u'gracehelbig')
# (88, u'graham')
# (12, u'grammy')
# (10, u'grammys')
# (9, u'gran')
# (31, u'grand')
# (6, u'grande')
# (34, u'grant')
# (5, u'graphic')
# (6, u'grass')
# (19, u'grassi')
# (7, u'grav3yardgirl')
# (13, u'gravitational')
# (7, u'gravity')
# (8, u'grayson')
# (19, u'great')
# (7, u'greatest')
# (141, u'green')
# (12, u'greg')
# (12, u'gregory')
# (46, u'grey')
# (15, u'grid')
# (14, u'grill')
# (14, u'grilling')
# (12, u'grinding')
# (8, u'grossman')
# (21, u'group')
# (6, u'grown')
# (37, u'grwm')
# (20, u'gryffin')
# (12, u'gt')
# (14, u'gta')
# (6, u'guard')
# (19, u'gucci')
# (8, u'guerrero')
# (35, u'guest')
# (7, u'guetta')
# (21, u'guide')
# (9, u'guilty')
# (19, u'guitar')
# (11, u'gummy')
# (90, u'gun')
# (5, u'gunaccessories')
# (9, u'gundam')
# (5, u'gunfire')
# (11, u'gunman')
# (6, u'gunpla')
# (9, u'guns')
# (56, u'guru')
# (62, u'gus')
# (10, u'gustoonz')
# (11, u'gutowski')
# (52, u'guy')
# (35, u'guys')
# (13, u'gwen')
# (8, u'gwyneth')
# (28, u'gyllenhaal')
# (18, u'gym')
# (10, u'gymnast')
# (66, u'gymnastics')
# (8, u'g\xf6khan')
# (26, u'hack')
# (30, u'hacks')
# (42, u'hadid')
# (8, u'haggard')
# (21, u'haiku')
# (118, u'hair')
# (6, u'hairstyle')
# (10, u'hairstyles')
# (9, u'haiti')
# (8, u'hal')
# (19, u'half')
# (30, u'hall')
# (547, u'halloween')
# (8, u'halsey')
# (39, u'hamburger')
# (8, u'hamdog')
# (7, u'hamilton')
# (37, u'hand')
# (12, u'handler')
# (87, u'hands')
# (9, u'handstand')
# (8, u'hangover')
# (32, u'hank')
# (5, u'hanna')
# (54, u'hannah')
# (33, u'hannahstocking')
# (5, u'hannibal')
# (7, u'hans')
# (9, u'hanson')
# (18, u'happen')
# (19, u'happened')
# (47, u'happens')
# (35, u'happiness')
# (94, u'happy')
# (6, u'harassment')
# (33, u'hard')
# (6, u'hardness')
# (16, u'hardware')
# (6, u'harington')
# (11, u'harmon')
# (19, u'harmony')
# (10, u'harris')
# (38, u'harrison')
# (62, u'harry')
# (27, u'hart')
# (9, u'harto')
# (8, u'harvest')
# (51, u'harvey')
# (7, u'hasbro')
# (11, u'hate')
# (16, u'haters')
# (112, u'haul')
# (17, u'haunted')
# (6, u'hauser')
# (8, u'havana')
# (32, u'have')
# (7, u'hawaii')
# (6, u'hawker')
# (6, u'hawkins')
# (26, u'hayes')
# (22, u'hbo')
# (45, u'hd')
# (27, u'head')
# (12, u'headlines')
# (7, u'headquarters')
# (108, u'health')
# (7, u'healthcare')
# (29, u'healthy')
# (10, u'hearing')
# (18, u'heart')
# (9, u'heartbreakers')
# (6, u'hearts')
# (12, u'heaux')
# (11, u'heaven')
# (6, u'heavy')
# (8, u'heckler')
# (9, u'hecox')
# (12, u'hedgehog')
# (52, u'hefner')
# (29, u'heidi')
# (8, u'heisman')
# (28, u'heist')
# (18, u'helbig')
# (11, u'helga')
# (23, u'hell')
# (6, u'hello')
# (27, u'help')
# (12, u'hemsworth')
# (5, u'henrique')
# (18, u'henry')
# (6, u'henson')
# (10, u'her')
# (5, u'herbo')
# (15, u'here')
# (17, u'heres')
# (33, u'hero')
# (6, u'hero4')
# (8, u'hero5')
# (11, u'hevesh5')
# (6, u'hex')
# (9, u'hey')
# (26, u'hi')
# (9, u'hi5')
# (28, u'hidden')
# (6, u'hide')
# (9, u'higa')
# (9, u'higatv')
# (130, u'high')
# (20, u'highest')
# (51, u'highlight')
# (22, u'highlighter')
# (6, u'highlighters')
# (67, u'highlights')
# (8, u'highway')
# (22, u'hijack')
# (12, u'hijacking')
# (80, u'hilarious')
# (28, u'hill')
# (23, u'hillary')
# (15, u'hills')
# (11, u'hindi')
# (94, u'hip')
# (9, u'hiphop')
# (5, u'hippo')
# (155, u'history')
# (27, u'hit')
# (15, u'hits')
# (12, u'hiv')
# (5, u'hoa')
# (8, u'hockey')
# (26, u'hoda')
# (6, u'hoes')
# (5, u'hogwarts')
# (43, u'hold')
# (12, u'hole')
# (19, u'holiday')
# (6, u'hollens')
# (6, u'holly')
# (9, u'hollyn')
# (169, u'hollywood')
# (19, u'holmes')
# (34, u'holo')
# (19, u'holographic')
# (5, u'holosexual')
# (6, u'holoween')
# (7, u'holt')
# (147, u'home')
# (6, u'homecoming')
# (41, u'homemade')
# (6, u'homes')
# (8, u'hometeam')
# (5, u'honda')
# (48, u'honest')
# (8, u'hoodie')
# (6, u'hoops')
# (94, u'hop')
# (7, u'hope')
# (10, u'hopes')
# (21, u'horan')
# (18, u'horizon')
# (21, u'horror')
# (16, u'horse')
# (8, u'hospital')
# (55, u'host')
# (6, u'hosts')
# (190, u'hot')
# (11, u'hot97')
# (12, u'hotdog')
# (30, u'hotel')
# (30, u'hottest')
# (8, u'hottie')
# (46, u'hour')
# (12, u'hours')
# (182, u'house')
# (18, u'housewives')
# (15, u'houston')
# (5, u'houten')
# (869, u'how')
# (18, u'howard')
# (11, u'howell')
# (10, u'howie')
# (7, u'howl')
# (6, u'howling')
# (14, u'howto')
# (19, u'hoying')
# (8, u'hshorts')
# (10, u'htc')
# (11, u'huang')
# (13, u'huckabee')
# (8, u'huda')
# (25, u'hudson')
# (30, u'huge')
# (53, u'hugh')
# (5, u'hugo')
# (10, u'hulk')
# (8, u'hulu')
# (14, u'human')
# (11, u'humanity')
# (26, u'humans')
# (160, u'humor')
# (28, u'humour')
# (8, u'hunger')
# (6, u'hungry')
# (19, u'hunt')
# (6, u'hunter')
# (10, u'hunting')
# (5, u'huricane')
# (263, u'hurricane')
# (9, u'hurricanes')
# (15, u'husband')
# (18, u'husky')
# (8, u'hustle')
# (5, u'hyper')
# (8, u'hyperhidrosis')
# (9, u'hywind')
# (23, u'ian')
# (10, u'icbm')
# (21, u'ice')
# (8, u'iceland')
# (15, u'icing')
# (6, u'iconic')
# (13, u'icp')
# (15, u'id')
# (19, u'idea')
# (62, u'ideas')
# (9, u'idiot')
# (11, u'idol')
# (5, u'idris')
# (39, u'if')
# (10, u'ifs')
# (10, u'ign')
# (8, u'iguana')
# (24, u'ii')
# (14, u'iii')
# (25, u'iisuperwomanii')
# (11, u'iisuperwomenii')
# (13, u'ijustine')
# (10, u'illenium')
# (16, u'illness')
# (8, u'illnyckj')
# (10, u'illusion')
# (13, u'ilnyckyi')
# (9, u'ilnyckyj')
# (25, u'im')
# (9, u'image')
# (12, u'images')
# (16, u'imagine')
# (6, u'imaginedragons')
# (22, u'impersonation')
# (9, u'impersonator')
# (23, u'impossible')
# (30, u'impression')
# (99, u'impressions')
# (28, u'improv')
# (9, u'improvement')
# (416, u'in')
# (37, u'inanna')
# (31, u'inannasarkis')
# (8, u'inc')
# (5, u'incident')
# (21, u'incredible')
# (9, u'independence')
# (17, u'independent')
# (19, u'indian')
# (11, u'indiana')
# (24, u'indie')
# (7, u'infant')
# (7, u'inflatable')
# (6, u'influencer')
# (16, u'infographics')
# (7, u'infomercial')
# (7, u'infomercials')
# (11, u'information')
# (6, u'ingredients')
# (21, u'ingrid')
# (9, u'injured')
# (9, u'injury')
# (5, u'inner')
# (19, u'innovation')
# (5, u'ins')
# (32, u'insane')
# (15, u'insects')
# (44, u'inside')
# (22, u'insider')
# (6, u'insomnia')
# (7, u'inspiral')
# (10, u'inspiration')
# (18, u'inspirational')
# (16, u'inspire')
# (8, u'inspired')
# (28, u'instagram')
# (6, u'install')
# (24, u'instant')
# (11, u'institute')
# (5, u'instrumental')
# (7, u'insults')
# (6, u'insurance')
# (6, u'interactive')
# (28, u'interesting')
# (5, u'interferometer')
# (13, u'interior')
# (24, u'international')
# (38, u'internet')
# (43, u'interscope')
# (340, u'interview')
# (51, u'interviews')
# (23, u'into')
# (9, u'inventions')
# (5, u'investigation')
# (5, u'invictus')
# (9, u'invitation')
# (28, u'ios')
# (6, u'ip')
# (6, u'ipad')
# (816, u'iphone')
# (5, u'iphone8')
# (9, u'iran')
# (8, u'iraq')
# (43, u'ireland')
# (5, u'irish')
# (7, u'irl')
# (146, u'irma')
# (24, u'iron')
# (27, u'irving')
# (277, u'is')
# (7, u'isaac')
# (13, u'isaiah')
# (7, u'isla')
# (37, u'island')
# (5, u'isle')
# (23, u'israel')
# (6, u'israeli')
# (16, u'iss')
# (7, u'issa')
# (5, u'issues')
# (14, u'istrefi')
# (403, u'it')
# (9, u'italian')
# (27, u'items')
# (16, u'its')
# (9, u'itsbl0ndie')
# (17, u'itsgrace')
# (6, u'itv')
# (10, u'iwb')
# (92, u'jack')
# (9, u'jacket')
# (30, u'jackie')
# (27, u'jacksfilms')
# (23, u'jackson')
# (18, u'jaclyn')
# (6, u'jaclynhill1')
# (14, u'jacob')
# (6, u'jacquard')
# (5, u'jaguar')
# (13, u'jahns')
# (14, u'jaiden')
# (22, u'jaidenanimation')
# (7, u'jaidenanimations')
# (6, u'jaime')
# (42, u'jake')
# (13, u'jam')
# (164, u'james')
# (53, u'jamie')
# (21, u'jane')
# (5, u'january')
# (29, u'japan')
# (16, u'japanese')
# (10, u'jared')
# (6, u'jash')
# (48, u'jason')
# (5, u'jauregui')
# (6, u'jauz')
# (8, u'javier')
# (26, u'jay')
# (12, u'jazeera')
# (19, u'jazz')
# (6, u'jazza')
# (15, u'jean')
# (13, u'jeans')
# (95, u'jedi')
# (6, u'jeep')
# (30, u'jeff')
# (41, u'jeffree')
# (10, u'jeffrey')
# (14, u'jemma')
# (12, u'jen')
# (6, u'jenkins')
# (9, u'jenn')
# (25, u'jenna')
# (84, u'jenner')
# (50, u'jennifer')
# (6, u'jepsen')
# (44, u'jeremy')
# (9, u'jerry')
# (6, u'jersey')
# (9, u'jesse')
# (16, u'jessi')
# (16, u'jessica')
# (15, u'jessie')
# (9, u'jesus')
# (16, u'jet')
# (6, u'jewish')
# (32, u'jibawi')
# (32, u'jim')
# (83, u'jimmy')
# (6, u'jj')
# (25, u'job')
# (29, u'jobs')
# (88, u'joe')
# (40, u'joes')
# (14, u'joey')
# (168, u'john')
# (19, u'johnny')
# (90, u'johnson')
# (57, u'joke')
# (71, u'jokes')
# (6, u'jolly')
# (47, u'jon')
# (22, u'jonas')
# (38, u'jonathan')
# (34, u'jones')
# (6, u'jong')
# (9, u'jorah')
# (56, u'jordan')
# (7, u'jordyn')
# (19, u'josh')
# (6, u'joshua')
# (5, u'journalism')
# (6, u'journey')
# (25, u'joy')
# (11, u'jr')
# (6, u'ju')
# (13, u'juan')
# (10, u'judge')
# (13, u'judges')
# (19, u'juggalo')
# (11, u'juggalos')
# (6, u'juicy')
# (8, u'julia')
# (5, u'julianne')
# (14, u'julien')
# (58, u'jumanji')
# (9, u'jump')
# (13, u'jumping')
# (18, u'jungle')
# (33, u'junkies')
# (11, u'jurassic')
# (50, u'just')
# (28, u'justice')
# (29, u'justin')
# (21, u'kaepernick')
# (5, u'kaley')
# (15, u'kaling')
# (7, u'kandee')
# (35, u'kane')
# (16, u'kansas')
# (17, u'kanye')
# (5, u'karan')
# (34, u'karaoke')
# (12, u'karate')
# (111, u'kardashian')
# (40, u'kardashians')
# (18, u'karen')
# (9, u'karma')
# (5, u'kasie')
# (58, u'kate')
# (13, u'kathie')
# (7, u'kati')
# (14, u'katie')
# (5, u'katniss')
# (5, u'katrina')
# (32, u'katy')
# (7, u'katze')
# (6, u'kaufman')
# (15, u'kawaii')
# (6, u'kayak')
# (10, u'kayley')
# (8, u'kb')
# (13, u'keanu')
# (7, u'keep')
# (26, u'keeping')
# (17, u'keith')
# (63, u'kelly')
# (7, u'kellyanne')
# (6, u'ken')
# (14, u'kendall')
# (8, u'kendo')
# (18, u'kendrick')
# (14, u'kennedy')
# (10, u'kenny')
# (7, u'kesha')
# (41, u'kevin')
# (27, u'key')
# (6, u'keyboard')
# (10, u'keys')
# (8, u'khaled')
# (5, u'khalessi')
# (35, u'khalid')
# (7, u'khloe')
# (5, u'kick')
# (59, u'kid')
# (8, u'kidinakorner')
# (12, u'kidman')
# (8, u'kidnapping')
# (166, u'kids')
# (6, u'kiiara')
# (7, u'kildall')
# (12, u'kill')
# (5, u'killawatt')
# (8, u'killer')
# (6, u'killing')
# (91, u'kim')
# (18, u'kimbra')
# (45, u'kimmel')
# (6, u'kimmy')
# (10, u'kinetic')
# (68, u'king')
# (10, u'kingdom')
# (7, u'kings')
# (16, u'kingsman')
# (5, u'kirsten')
# (5, u'kiss')
# (7, u'kissing')
# (18, u'kit')
# (139, u'kitchen')
# (7, u'kits')
# (32, u'kitten')
# (9, u'kittens')
# (13, u'kitty')
# (36, u'kj')
# (20, u'kkw')
# (10, u'klay')
# (13, u'klg')
# (11, u'klum')
# (8, u'knee')
# (14, u'knicks')
# (12, u'knife')
# (5, u'knockout')
# (57, u'know')
# (5, u'knowledge')
# (6, u'knowledgehub')
# (7, u'knows')
# (6, u'ko')
# (5, u'koa')
# (24, u'kodak')
# (80, u'kodaline')
# (9, u'koenigsegg')
# (5, u'kordei')
# (50, u'korea')
# (25, u'korean')
# (5, u'koreanenglish')
# (46, u'koshy')
# (21, u'kourtney')
# (11, u'krasinski')
# (14, u'kris')
# (17, u'kristen')
# (28, u'kroll')
# (7, u'kubrick')
# (13, u'kumail')
# (5, u'kurt')
# (7, u'kurzgesagt')
# (21, u'kuwtk')
# (16, u'kygo')
# (11, u'kyle')
# (84, u'kylie')
# (22, u'kylo')
# (27, u'kyrie')
# (5, u'l33t')
# (66, u'la')
# (46, u'label')
# (6, u'labor')
# (9, u'lad')
# (21, u'lady')
# (8, u'ladylike')
# (7, u'lag')
# (7, u'lake')
# (12, u'lamar')
# (11, u'lamborghini')
# (9, u'lambs')
# (6, u'lancaster')
# (19, u'land')
# (19, u'language')
# (20, u'lannister')
# (18, u'lantern')
# (6, u'large')
# (16, u'largest')
# (7, u'larry')
# (6, u'larvae')
# (159, u'las')
# (22, u'laser')
# (5, u'lash')
# (17, u'lashes')
# (194, u'last')
# (5, u'lasting')
# (379, u'late')
# (12, u'lately')
# (10, u'latest')
# (16, u'latin')
# (6, u'latina')
# (10, u'lauder')
# (63, u'laugh')
# (8, u'laughing')
# (5, u'laughter')
# (20, u'launch')
# (47, u'laura')
# (147, u'laurdiy')
# (48, u'lauren')
# (17, u'laurex')
# (20, u'lava')
# (24, u'lavar')
# (8, u'lavigne')
# (21, u'law')
# (5, u'lawnmower')
# (28, u'lawrence')
# (22, u'laws')
# (10, u'lawyer')
# (9, u'lay')
# (9, u'lazy')
# (8, u'lea')
# (7, u'lead')
# (5, u'leaf')
# (30, u'league')
# (26, u'leak')
# (65, u'learn')
# (5, u'learned')
# (17, u'learning')
# (19, u'learns')
# (5, u'learnt')
# (10, u'leaving')
# (26, u'lebron')
# (10, u'lecrae')
# (5, u'lecter')
# (8, u'lecture')
# (54, u'lee')
# (5, u'leet')
# (11, u'leg')
# (6, u'legal')
# (5, u'legally')
# (20, u'legend')
# (6, u'legends')
# (60, u'lego')
# (5, u'legos')
# (8, u'lehrstuhl')
# (11, u'leigh')
# (41, u'lele')
# (37, u'lelepons')
# (13, u'lemon')
# (7, u'lena')
# (37, u'lens')
# (21, u'les')
# (25, u'lesbian')
# (10, u'leslie')
# (11, u'less')
# (9, u'lessons')
# (21, u'let')
# (10, u'lets')
# (49, u'letterman')
# (6, u'level')
# (11, u'levi')
# (9, u'levin')
# (13, u'levine')
# (9, u'lewinsky')
# (15, u'lewis')
# (13, u'lexus')
# (23, u'lg')
# (35, u'lgbt')
# (9, u'lgbtq')
# (38, u'li')
# (48, u'liam')
# (5, u'liberal')
# (11, u'library')
# (6, u'licence')
# (7, u'license')
# (7, u'lie')
# (20, u'lies')
# (184, u'life')
# (95, u'lifestyle')
# (6, u'lifetime')
# (6, u'lift')
# (43, u'light')
# (5, u'lighting')
# (8, u'lightning')
# (5, u'lights')
# (8, u'ligo')
# (96, u'like')
# (9, u'likes')
# (21, u'lil')
# (36, u'lilly')
# (52, u'lily')
# (20, u'lim')
# (9, u'lima')
# (5, u'limo')
# (11, u'lin')
# (6, u'lincoln')
# (12, u'lindsay')
# (24, u'lindsey')
# (69, u'line')
# (8, u'lines')
# (155, u'link')
# (8, u'linkin')
# (24, u'lion')
# (15, u'lions')
# (13, u'lionsgate')
# (53, u'lip')
# (11, u'lipgloss')
# (8, u'lips')
# (54, u'lipstick')
# (29, u'liquid')
# (19, u'lisa')
# (9, u'list')
# (17, u'listen')
# (5, u'lit')
# (14, u'literally')
# (8, u'literature')
# (87, u'little')
# (447, u'live')
# (12, u'lively')
# (25, u'liver')
# (9, u'lives')
# (23, u'living')
# (129, u'liza')
# (17, u'lizakoshy')
# (15, u'lizard')
# (17, u'lizza')
# (20, u'lizzza')
# (17, u'lizzzak')
# (13, u'lizzzako')
# (17, u'lizzzavine')
# (7, u'll')
# (17, u'llc')
# (11, u'llsuperwomanll')
# (8, u'lo')
# (5, u'loc')
# (16, u'local')
# (97, u'logan')
# (10, u'logang')
# (47, u'lol')
# (5, u'lollies')
# (6, u'loma')
# (69, u'london')
# (34, u'lonely')
# (87, u'long')
# (6, u'longer')
# (5, u'lonzo')
# (97, u'look')
# (15, u'lookbook')
# (11, u'looks')
# (8, u'lopez')
# (25, u'lore')
# (5, u'lorraine')
# (39, u'los')
# (23, u'lose')
# (6, u'losers')
# (30, u'losing')
# (24, u'loss')
# (21, u'lost')
# (18, u'loud')
# (6, u'louis')
# (6, u'louise')
# (7, u'louisiana')
# (12, u'lounge')
# (59, u'lovato')
# (184, u'love')
# (5, u'loved')
# (6, u'lover')
# (10, u'lovers')
# (17, u'loving')
# (74, u'low')
# (6, u'lowry')
# (11, u'lucas')
# (5, u'lucasfilm')
# (15, u'lucie')
# (6, u'lucky')
# (8, u'luis')
# (7, u'luka')
# (41, u'luke')
# (8, u'lunch')
# (11, u'luther')
# (6, u'lux')
# (26, u'luxury')
# (6, u'ly')
# (33, u'lynch')
# (50, u'lyric')
# (82, u'lyrics')
# (61, u'mac')
# (8, u'macaroni')
# (26, u'macarons')
# (14, u'macdonald')
# (5, u'machete')
# (39, u'machine')
# (10, u'macklemore')
# (10, u'mad')
# (64, u'made')
# (8, u'madebygoogle')
# (32, u'madelaine')
# (15, u'madelainepetsch')
# (14, u'madison')
# (5, u'madrid')
# (8, u'mae')
# (9, u'mafia')
# (49, u'magazine')
# (20, u'maggie')
# (41, u'magic')
# (6, u'magnitude')
# (6, u'mahnke')
# (6, u'maia')
# (21, u'mail')
# (10, u'maisie')
# (9, u'major')
# (242, u'make')
# (41, u'makeover')
# (9, u'makeovers')
# (7, u'maker')
# (9, u'makes')
# (982, u'makeup')
# (41, u'making')
# (13, u'makrides')
# (10, u'male')
# (9, u'malibu')
# (6, u'mama')
# (6, u'mamrie')
# (149, u'man')
# (15, u'management')
# (6, u'manal')
# (8, u'mancuso')
# (34, u'mandalay')
# (10, u'mandel')
# (11, u'mane')
# (5, u'manga')
# (9, u'manic')
# (8, u'mannequin')
# (12, u'mannequins')
# (26, u'manny')
# (8, u'mannymua')
# (7, u'manuel')
# (20, u'manufacturers')
# (8, u'manufacturing')
# (8, u'many')
# (40, u'map')
# (17, u'maps')
# (6, u'marano')
# (8, u'marathon')
# (25, u'marbles')
# (15, u'marc')
# (14, u'march')
# (22, u'maria')
# (16, u'mariah')
# (13, u'marie')
# (7, u'marine')
# (21, u'mario')
# (42, u'mark')
# (20, u'market')
# (20, u'marketplace')
# (9, u'marmalade')
# (7, u'marr')
# (13, u'marriage')
# (26, u'mars')
# (10, u'marseille')
# (7, u'marshall')
# (37, u'marshemllo')
# (86, u'marshmello')
# (6, u'marshmellow')
# (16, u'marston')
# (7, u'mart')
# (17, u'martial')
# (29, u'martin')
# (10, u'martina')
# (70, u'marvel')
# (13, u'mary')
# (15, u'mascara')
# (37, u'mash')
# (10, u'mashup')
# (14, u'mask')
# (43, u'mass')
# (8, u'massacre')
# (7, u'masseduction')
# (6, u'master')
# (11, u'matarazzo')
# (6, u'match')
# (11, u'math')
# (22, u'matpat')
# (33, u'matt')
# (8, u'matte')
# (5, u'matter')
# (13, u'matthew')
# (12, u'matthias')
# (9, u'matthiasiam')
# (23, u'maverick')
# (30, u'max')
# (36, u'may')
# (12, u'maya')
# (9, u'maybelline')
# (9, u'mayor')
# (9, u'mayweather')
# (29, u'maze')
# (15, u'mccain')
# (9, u'mccarthy')
# (19, u'mccormack')
# (33, u'mcdonald')
# (48, u'mcdonalds')
# (10, u'mcfarland')
# (9, u'mcgraw')
# (35, u'mckinnon')
# (5, u'mclaren')
# (5, u'mclaughlin')
# (6, u'mclendon')
# (9, u'mcmuffin')
# (13, u'mcu')
# (238, u'me')
# (9, u'meal')
# (34, u'mean')
# (9, u'meaning')
# (10, u'meant')
# (20, u'meat')
# (6, u'mech')
# (8, u'mechanical')
# (9, u'mechanics')
# (16, u'medallions')
# (74, u'media')
# (5, u'medicaid')
# (5, u'medical')
# (14, u'medicine')
# (33, u'meet')
# (11, u'meetarnold')
# (5, u'mega')
# (67, u'megan')
# (9, u'megatoad')
# (15, u'megyn')
# (8, u'mehdi')
# (12, u'mel')
# (5, u'melanie')
# (5, u'melbourne')
# (27, u'melissa')
# (6, u'melo')
# (5, u'melting')
# (38, u'meme')
# (10, u'memes')
# (87, u'men')
# (9, u'mendes')
# (54, u'mental')
# (16, u'menu')
# (7, u'mercedes')
# (23, u'merch')
# (12, u'mercury')
# (9, u'meringue')
# (10, u'merle')
# (12, u'mermaid')
# (15, u'merrell')
# (9, u'mess')
# (16, u'message')
# (5, u'messenger')
# (19, u'messing')
# (5, u'messy')
# (15, u'metal')
# (14, u'metallic')
# (5, u'mexican')
# (57, u'mexico')
# (71, u'meyers')
# (6, u'mgm')
# (19, u'mi')
# (8, u'miami')
# (79, u'michael')
# (9, u'michaels')
# (8, u'michele')
# (38, u'michelle')
# (5, u'michigan')
# (25, u'mickey')
# (5, u'microbes')
# (8, u'microsoft')
# (11, u'microwave')
# (17, u'middle')
# (8, u'midweek')
# (9, u'migos')
# (5, u'mika')
# (47, u'mike')
# (16, u'milani')
# (6, u'mile')
# (43, u'miley')
# (13, u'military')
# (22, u'milk')
# (24, u'miller')
# (6, u'millie')
# (17, u'million')
# (8, u'milo')
# (10, u'minaj')
# (19, u'mind')
# (12, u'mindfullness')
# (15, u'mindy')
# (5, u'minecraft')
# (57, u'mini')
# (5, u'miniseries')
# (5, u'minister')
# (47, u'minute')
# (11, u'minuteearth')
# (20, u'minutephysics')
# (8, u'minutes')
# (5, u'mir')
# (41, u'miranda')
# (12, u'mirror')
# (8, u'mirrors')
# (16, u'miso')
# (17, u'miss')
# (15, u'misses')
# (9, u'missglamorazzi')
# (5, u'missguided')
# (8, u'missile')
# (8, u'mission')
# (5, u'missions')
# (12, u'mistakes')
# (22, u'mitch')
# (24, u'mitchell')
# (9, u'mix')
# (8, u'mixed')
# (16, u'mixing')
# (9, u'mkay')
# (21, u'mkbhd')
# (17, u'mlb')
# (14, u'mma')
# (5, u'mmooney')
# (6, u'mnf')
# (16, u'mo')
# (10, u'moana')
# (16, u'mobile')
# (5, u'moc')
# (6, u'mocumentary')
# (13, u'mode')
# (48, u'model')
# (5, u'models')
# (10, u'moffat')
# (12, u'mohs')
# (5, u'moisture')
# (33, u'mom')
# (11, u'moment')
# (23, u'moments')
# (7, u'momoa')
# (7, u'moms')
# (12, u'monday')
# (7, u'mondays')
# (49, u'money')
# (11, u'monica')
# (62, u'monologue')
# (6, u'monopoly')
# (54, u'monster')
# (6, u'monsters')
# (17, u'montana')
# (17, u'month')
# (8, u'monthly')
# (6, u'mood')
# (57, u'moon')
# (7, u'moons')
# (19, u'moore')
# (26, u'moose')
# (64, u'more')
# (10, u'morello')
# (12, u'morgan')
# (15, u'morin')
# (15, u'mormont')
# (123, u'morning')
# (10, u'morris')
# (8, u'morrison')
# (7, u'morrissey')
# (11, u'morton')
# (142, u'morty')
# (7, u'mosquito')
# (98, u'most')
# (6, u'mota')
# (24, u'mother')
# (6, u'motherhood')
# (49, u'motion')
# (6, u'motivation')
# (6, u'motivational')
# (6, u'moto')
# (8, u'motor')
# (22, u'mount')
# (7, u'mountain')
# (8, u'mourey')
# (12, u'mouse')
# (7, u'move')
# (9, u'movement')
# (471, u'movie')
# (197, u'movies')
# (40, u'mr')
# (33, u'msnbc')
# (25, u'mtv')
# (47, u'mua')
# (50, u'much')
# (9, u'muffin')
# (9, u'muffins')
# (5, u'mukbang')
# (5, u'mulan')
# (6, u'mulder')
# (64, u'mullally')
# (5, u'mumbai')
# (24, u'munn')
# (10, u'murder')
# (11, u'murphy')
# (12, u'museum')
# (727, u'music')
# (54, u'musical')
# (27, u'musician')
# (10, u'musk')
# (8, u'muslim')
# (14, u'must')
# (9, u'mustache')
# (8, u'mustang')
# (20, u'mutants')
# (206, u'my')
# (14, u'mykie')
# (16, u'mylifeaseva')
# (7, u'myself')
# (22, u'mystery')
# (96, u'mythical')
# (161, u'nail')
# (17, u'nailogical')
# (72, u'nails')
# (8, u'nam')
# (34, u'name')
# (22, u'names')
# (6, u'nancy')
# (13, u'nanjiani')
# (13, u'nap')
# (48, u'nasa')
# (65, u'nashville')
# (7, u'nation')
# (51, u'national')
# (6, u'nationals')
# (7, u'nations')
# (9, u'native')
# (37, u'natural')
# (23, u'nature')
# ...
# (7, u'simplyfacelogical')
# (24, u'simplynailogical')
# (16, u'simpson')
# (21, u'simulation')
# (5, u'simulator')
# (5, u'sinfield')
# (43, u'sing')
# (23, u'singapore')
# (39, u'singer')
# (11, u'singers')
# (34, u'singh')
# (29, u'singing')
# (43, u'single')
# (25, u'sings')
# (12, u'sinkhole')
# (12, u'sins')
# (7, u'siouxsie')
# (6, u'sir')
# (7, u'sirens')
# (9, u'sister')
# (5, u'sisyphus')
# (10, u'six')
# (9, u'size')
# (19, u'sj')
# (7, u'sju')
# (11, u'skarsgard')
# (7, u'skateboard')
# (173, u'sketch')
# (24, u'sketches')
# (13, u'skills')
# (56, u'skin')
# (53, u'skincare')
# (6, u'skip')
# (22, u'skit')
# (24, u'skits')
# (17, u'skull')
# (7, u'skylar')
# (5, u'skywalk')
# (10, u'slave')
# (6, u'sledgehammer')
# (45, u'sleep')
# (11, u'sleeping')
# (13, u'slide')
# (15, u'slime')
# (28, u'slow')
# (6, u'slushi')
# (14, u'slushii')
# (9, u'smackdown')
# (17, u'small')
# (18, u'smart')
# (12, u'smarter')
# (30, u'smartphone')
# (9, u'smash')
# (25, u'smile')
# (15, u'smiles')
# (100, u'smith')
# (7, u'smiths')
# (13, u'smoke')
# (6, u'smokey')
# (6, u'smoothie')
# (37, u'smosh')
# (57, u'snake')
# (10, u'snakes')
# (5, u'snapchat')
# (16, u'sneak')
# (10, u'sneaker')
# (6, u'sneakerhead')
# (12, u'sneakers')
# (6, u'snes')
# (125, u'snl')
# (5, u'snoke')
# (19, u'snow')
# (8, u'snyder')
# (23, u'so')
# (8, u'soap')
# (21, u'sober')
# (57, u'soccer')
# (27, u'social')
# (7, u'society')
# (6, u'soda')
# (6, u'sodium')
# (6, u'sofia')
# (17, u'soft')
# (5, u'software')
# (38, u'solar')
# (5, u'sold')
# (21, u'soldiers')
# (11, u'solo')
# (9, u'solomita')
# (7, u'somebody')
# (5, u'someone')
# (5, u'something')
# (6, u'sometime')
# (17, u'son')
# (222, u'song')
# (26, u'songs')
# (16, u'songwriter')
# (13, u'sonic')
# (5, u'sonja')
# (6, u'sons')
# (37, u'sony')
# (10, u'soon')
# (12, u'sophia')
# (10, u'sophie')
# (29, u'sorry')
# (17, u'sortedfood')
# (17, u'soul')
# (10, u'soulpancake')
# (5, u'souls')
# (27, u'sound')
# (12, u'sounds')
# (11, u'soundtrack')
# (54, u'soup')
# (6, u'sour')
# (25, u'south')
# (8, u'southern')
# (6, u'southwest')
# (314, u'sp')
# (5, u'spa')
# (102, u'space')
# (10, u'spacecraft')
# (7, u'spaces')
# (5, u'spacey')
# (21, u'spain')
# (10, u'spanish')
# (12, u'spark')
# (6, u'sparrow')
# (16, u'speak')
# (8, u'speaker')
# (40, u'special')
# (5, u'specialfx')
# (8, u'species')
# (12, u'specs')
# (42, u'speech')
# (29, u'speed')
# (8, u'speedway')
# (17, u'spencer')
# (11, u'spf')
# (6, u'spfx')
# (58, u'spice')
# (5, u'spiced')
# (7, u'spicer')
# (56, u'spicy')
# (75, u'spider')
# (6, u'spidercat')
# (20, u'spiderman')
# (5, u'spiderweb')
# (5, u'spielberg')
# (5, u'spike')
# (5, u'spill')
# (5, u'spilling')
# (36, u'spinner')
# (28, u'spinners')
# (6, u'spinning')
# (5, u'spiny')
# (10, u'spiral')
# (13, u'spirit')
# (5, u'spoiler')
# (5, u'sponge')
# (17, u'spoof')
# (30, u'spooky')
# (7, u'spoopy')
# (40, u'sport')
# (164, u'sports')
# (6, u'spr')
# (10, u'spray')
# (7, u'spring')
# (20, u'sprint')
# (6, u'spy')
# (7, u'squad')
# (20, u'square')
# (6, u'squeeze')
# (61, u'st')
# (8, u'stache')
# (9, u'stadium')
# (10, u'stamos')
# (63, u'stand')
# (6, u'stanley')
# (209, u'star')
# (6, u'starbucks')
# (16, u'stark')
# (10, u'starrr')
# (103, u'stars')
# (10, u'start')
# (5, u'starz')
# (37, u'state')
# (18, u'states')
# (11, u'stateshot97')
# (39, u'station')
# (9, u'statoil')
# (22, u'stay')
# (41, u'steak')
# (9, u'steals')
# (6, u'steam')
# (10, u'steampunk')
# (11, u'steel')
# (10, u'steele')
# (15, u'steering')
# (13, u'stefani')
# (40, u'step')
# (9, u'stephanie')
# (135, u'stephen')
# (12, u'steps')
# (6, u'stereotypes')
# (16, u'sterling')
# (11, u'stern')
# (40, u'steve')
# (72, u'steven')
# (7, u'stewart')
# (14, u'stick')
# (16, u'sticker')
# (5, u'stigma')
# (14, u'sting')
# (12, u'stirling')
# (33, u'stock')
# (21, u'stocking')
# (11, u'stomach')
# (41, u'stone')
# (9, u'stonie')
# (16, u'stop')
# (5, u'stopped')
# (13, u'storage')
# (75, u'store')
# (49, u'stories')
# (60, u'storm')
# (97, u'story')
# (12, u'storytelling')
# (10, u'storytime')
# (8, u'strait')
# (6, u'stranded')
# (42, u'strange')
# (37, u'stranger')
# (6, u'strangers')
# (6, u'strawberry')
# (27, u'stream')
# (44, u'streaming')
# (23, u'streamy')
# (37, u'streamys')
# (111, u'street')
# (20, u'strength')
# (15, u'stress')
# (8, u'stringwork')
# (7, u'strip')
# (9, u'strong')
# (6, u'structure')
# (9, u'struggle')
# (8, u'stuck')
# (7, u'student')
# (15, u'studio')
# (8, u'studioc')
# (37, u'studios')
# (20, u'study')
# (7, u'stuff')
# (8, u'stuffed')
# (10, u'stunt')
# (26, u'stupid')
# (120, u'style')
# (14, u'styles')
# (6, u'subculture')
# (6, u'subscribers')
# (10, u'success')
# (6, u'sucessful')
# (15, u'suck')
# (6, u'sucks')
# (5, u'sudeikis')
# (6, u'sue')
# (7, u'suede')
# (32, u'sugar')
# (11, u'sugg')
# (12, u'suit')
# (15, u'suits')
# (8, u'sullivan')
# (36, u'summer')
# (19, u'sun')
# (10, u'sunday')
# (7, u'sunset')
# (129, u'super')
# (17, u'supercarlinbrothers')
# (18, u'superfruit')
# (24, u'superhero')
# (8, u'superman')
# (20, u'supermodel')
# (8, u'supernatural')
# (10, u'superstars')
# (21, u'superwoman')
# (11, u'superwomen')
# (8, u'supplies')
# (7, u'supply')
# (44, u'support')
# (11, u'surgery')
# (22, u'surprise')
# (24, u'survival')
# (22, u'survive')
# (7, u'surviving')
# (7, u'survivor')
# (45, u'sushi')
# (6, u'suspense')
# (13, u'swaim')
# (13, u'swap')
# (10, u'swatches')
# (8, u'sweat')
# (6, u'sweating')
# (21, u'sweet')
# (16, u'sweets')
# (53, u'swift')
# (15, u'swimming')
# (33, u'swiss')
# (23, u'switch')
# (7, u'sword')
# (6, u'sxephil')
# (15, u'syco')
# (6, u'sydney')
# (22, u'syfy')
# (6, u'sykes')
# (13, u'sync')
# (6, u'syndrome')
# (6, u'syria')
# (15, u'syrup')
# (27, u'system')
# (7, u'systems')
# (10, u'szechaun')
# (5, u'szechon')
# (50, u'szechuan')
# (5, u'szechuansauce')
# (5, u'szewan')
# (5, u'szezchuan')
# (28, u'taco')
# (12, u'tag')
# (10, u'tags')
# (5, u'tai')
# (8, u'tail')
# (94, u'take')
# (14, u'takeover')
# (15, u'takes')
# (17, u'taking')
# (9, u'tale')
# (111, u'talent')
# (168, u'talk')
# (11, u'talking')
# (5, u'talks')
# (10, u'tamar')
# (8, u'tamara')
# (14, u'tangled')
# (7, u'tango')
# (5, u'tank')
# (22, u'tanner')
# (7, u'tape')
# (8, u'tardigrade')
# (10, u'targaryen')
# (14, u'target')
# (132, u'taste')
# (7, u'tasting')
# (22, u'tasty')
# (6, u'tati')
# (10, u'tattoos')
# (28, u'tax')
# (29, u'taxes')
# (5, u'taxi')
# (11, u'tayla')
# (102, u'taylor')
# (13, u'tbs')
# (30, u'td')
# (21, u'tea')
# (39, u'teacher')
# (8, u'teachers')
# (11, u'teaching')
# (58, u'team')
# (33, u'teaser')
# (144, u'tech')
# (5, u'technic')
# (5, u'techno')
# (72, u'technology')
# (63, u'ted')
# (25, u'teen')
# (9, u'teenagers')
# (16, u'teens')
# (10, u'teeth')
# (6, u'telegraph')
# (10, u'teleported')
# (147, u'television')
# (29, u'tell')
# (14, u'temperature')
# (12, u'temperatures')
# (13, u'ten')
# (12, u'tennessee')
# (8, u'tennis')
# (8, u'terrelle')
# (32, u'terrier')
# (13, u'terror')
# (6, u'terrorism')
# (5, u'terrorist')
# (8, u'tesla')
# (300, u'test')
# (23, u'tested')
# (11, u'testedcom')
# (12, u'testing')
# (26, u'texas')
# (8, u'texts')
# (28, u'tfb')
# (6, u'tfl')
# (5, u'tha')
# (10, u'thaad')
# (15, u'than')
# (67, u'that')
# (11, u'thataylaa')
# (6, u'thats')
# (2192, u'the')
# (19, u'theater')
# (6, u'thee')
# (8, u'theepatrickstarrr')
# (7, u'thefinebros')
# (5, u'theft')
# (6, u'thegabbieshow')
# (14, u'theinfographicsshow')
# (31, u'theme')
# (18, u'themed')
# (24, u'theories')
# (15, u'theorists')
# (105, u'theory')
# (5, u'theraphy')
# (5, u'therapist')
# (44, u'therapy')
# (22, u'there')
# (24, u'theresa')
# (15, u'these')
# (9, u'theundervlogs')
# (6, u'thieves')
# (17, u'thing')
# (102, u'things')
# (17, u'think')
# (5, u'thinking')
# (107, u'this')
# (58, u'thomas')
# (16, u'thompson')
# (27, u'thor')
# (32, u'thorne')
# (6, u'thought')
# (21, u'thoughts')
# (10, u'threadbanger')
# (7, u'three')
# (27, u'thrift')
# (6, u'thrifting')
# (19, u'thriller')
# (6, u'throne')
# (57, u'thrones')
# (16, u'through')
# (20, u'thru')
# (6, u'thumbnails')
# (32, u'thunder')
# (6, u'thursday')
# (90, u'ti')
# (24, u'tickets')
# (12, u'tide')
# (33, u'tiesto')
# (6, u'tiff')
# (21, u'till')
# (6, u'tiller')
# (33, u'tim')
# (118, u'time')
# (8, u'timelapse')
# (65, u'times')
# (8, u'tina')
# (58, u'tinder')
# (27, u'tiny')
# (93, u'tips')
# (8, u'tires')
# (14, u'tisdale')
# (6, u'tistos')
# (8, u'tizzietuesday')
# (7, u'ti\xebsto')
# (60, u'tmz')
# (15, u'tmz2016fs11221')
# (51, u'tnt')
# (1083, u'to')
# (9, u'tobeornottobethatisthequestion')
# (119, u'today')
# (15, u'toddler')
# (6, u'toe')
# (21, u'tofield')
# (8, u'together')
# (5, u'toilet')
# (8, u'tokyo')
# (120, u'tom')
# (17, u'tomahawk')
# (41, u'tomb')
# (7, u'tomenosuke')
# (6, u'tomlinson')
# (15, u'tommy')
# (6, u'tomorrow')
# (8, u'tomscott')
# (9, u'toni')
# (67, u'tonight')
# (7, u'tony')
# (93, u'too')
# (13, u'tool')
# (22, u'tools')
# (7, u'toons')
# (124, u'top')
# (13, u'topic')
# (8, u'topp')
# (8, u'topper')
# (22, u'toronto')
# (12, u'tory')
# (24, u'total')
# (24, u'touchdown')
# (6, u'touchdowns')
# (108, u'tour')
# (10, u'tourism')
# (5, u'tove')
# (18, u'tower')
# (21, u'town')
# (11, u'toxic')
# (29, u'toy')
# (10, u'toyota')
# (38, u'toys')
# (16, u'tracee')
# (10, u'track')
# (27, u'trade')
# (5, u'traded')
# (50, u'trader')
# (8, u'traditional')
# (7, u'traffic')
# (20, u'trail')
# (569, u'trailer')
# (27, u'trailers')
# (11, u'train')
# (5, u'trainer')
# (31, u'training')
# (8, u'trans')
# (35, u'transformation')
# (13, u'trap')
# (16, u'trash')
# (7, u'trauma')
# (106, u'travel')
# (13, u'traveler')
# (12, u'traveling')
# (31, u'travis')
# (27, u'treat')
# (5, u'treatment')
# (12, u'tree')
# (11, u'trek')
# (10, u'trend')
# (59, u'trending')
# (38, u'trends')
# (30, u'trevor')
# (5, u'tri')
# (5, u'trial')
# (6, u'trials')
# (8, u'triathlon')
# (59, u'trick')
# (54, u'tricks')
# (5, u'tries')
# (8, u'trike')
# (6, u'trinidad')
# (11, u'trip')
# (13, u'triple')
# (12, u'trivia')
# (8, u'trl')
# (9, u'troll')
# (10, u'trolling')
# (7, u'trooper')
# (6, u'trop')
# (16, u'trophy')
# (5, u'tropical')
# (15, u'truck')
# (35, u'true')
# (8, u'truetv')
# (10, u'truman')
# (266, u'trump')
# (26, u'truth')
# (52, u'trutv')
# (88, u'try')
# (38, u'trying')
# (15, u'tub')
# (22, u'tube')
# (10, u'tuesday')
# (5, u'turbo')
# (9, u'turismo')
# (6, u'turn')
# (11, u'turner')
# (9, u'turtle')
# (17, u'turtles')
# (8, u'tut')
# (489, u'tutorial')
# (41, u'tutorials')
# (6, u'tux')
# (310, u'tv')
# (6, u'tw')
# (10, u'twain')
# (7, u'tweet')
# (30, u'tweets')
# (9, u'twellman')
# (5, u'twenty')
# (16, u'twice')
# (17, u'twin')
# (69, u'twins')
# (7, u'twist')
# (56, u'twitter')
# (25, u'two')
# (46, u'ty')
# (40, u'tyler')
# (6, u'tyleroakley')
# (28, u'types')
# (10, u'tyra')
# (8, u'tyrion')
# (12, u'tyson')
# (5, u'u2')
# (9, u'uac')
# (23, u'uber')
# (52, u'ufc')
# (5, u'ugly')
# (50, u'uk')
# (42, u'ultimate')
# (39, u'ultra')
# (15, u'umbrella')
# (28, u'un')
# (8, u'unashamed')
# (31, u'unbox')
# (167, u'unboxing')
# (14, u'unboxtherapy')
# (15, u'uncle')
# (22, u'under')
# (5, u'underground')
# (6, u'undertaker')
# (12, u'undervlogs')
# (5, u'underwood')
# (7, u'unhealthy')
# (5, u'unicorn')
# (7, u'unidos')
# (12, u'union')
# (13, u'unique')
# (40, u'united')
# (24, u'universal')
# (23, u'universe')
# (21, u'university')
# (11, u'unlock')
# (203, u'up')
# (8, u'upchurch')
# (55, u'update')
# (19, u'updates')
# (10, u'upgrade')
# (8, u'upload')
# (5, u'ups')
# (5, u'uranus')
# (12, u'uravgconsumer')
# (18, u'urban')
# (212, u'us')
# (5, u'us1a')
# (42, u'usa')
# (6, u'usafa')
# (8, u'usatsyn')
# (8, u'usatyoutube')
# (12, u'usb')
# (19, u'used')
# (9, u'useless')
# (11, u'uses')
# (8, u'using')
# (18, u'usmnt')
# (6, u'uthaug')
# (8, u'vacation')
# (10, u'valley')
# (5, u'vamp')
# (13, u'vampy')
# (14, u'van')
# (9, u'vanessa')
# (56, u'vanilla')
# (18, u'vanity')
# (19, u'variety')
# (7, u'vat19')
# (8, u'vaynerchuk')
# (5, u'vaynermedia')
# (22, u'vegan')
# (183, u'vegas')
# (12, u'vegetarian')
# (14, u'vehicle')
# (12, u'velcro')
# (7, u'venice')
# (12, u'venom')
# (29, u'verge')
# (12, u'veronica')
# (9, u'version')
# (7, u'versus')
# (19, u'vevo')
# (9, u'vf')
# (8, u'vfx')
# (14, u'vice')
# (17, u'victoria')
# (9, u'vidcon')
# (955, u'video')
# (219, u'videos')
# (14, u'view')
# (14, u'views')
# (8, u'viii')
# (9, u'vikander')
# (6, u'village')
# (7, u'villasenor')
# (12, u'vince')
# (8, u'vincent')
# (29, u'vine')
# (16, u'vines')
# (6, u'vintage')
# (12, u'violence')
# (8, u'violin')
# (75, u'viral')
# (12, u'viralhog')
# (8, u'virgo')
# (16, u'virtual')
# (5, u'visa')
# (6, u'vista')
# (6, u'visual')
# (24, u'vitale')
# (30, u'vives')
# (38, u'vl')
# (5, u'vladimir')
# (324, u'vlog')
# (8, u'vlogbrothers')
# (69, u'vlogger')
# (6, u'vloggers')
# (56, u'vlogging')
# (147, u'vlogs')
# (8, u'vlogs2017')
# (7, u'vocal')
# (46, u'vogue')
# (102, u'voice')
# (32, u'voicenotes')
# (8, u'voldemort')
# (6, u'volpe')
# (5, u'volvo')
# (17, u'vote')
# (51, u'vox')
# (8, u'vpc')
# (13, u'vr')
# (362, u'vs')
# (6, u'vsauce3')
# (9, u'vulnerable')
# (5, u'vw')
# (7, u'vydia')
# (22, u'wade')
# (6, u'waiting')
# (8, u'waldau')
# (34, u'walk')
# (10, u'walken')
# (62, u'walker')
# (6, u'walking')
# (10, u'wall')
# (14, u'wallpaper')
# (7, u'walls')
# (15, u'walmart')
# (17, u'walt')
# (6, u'walton')
# (6, u'wanda')
# (8, u'wanna')
# (11, u'want')
# (62, u'war')
# (11, u'wardrobe')
# (5, u'warming')
# (51, u'warner')
# (5, u'warning')
# (17, u'warriors')
# (130, u'wars')
# (14, u'was')
# (46, u'washington')
# (119, u'wassabi')
# (9, u'wassabians')
# (202, u'watch')
# (73, u'water')
# (12, u'waterfall')
# (5, u'waterford')
# (10, u'watermelon')
# (21, u'waterproof')
# (5, u'watford')
# (7, u'watkins')
# (8, u'watters')
# (7, u'wave')
# (9, u'waves')
# (49, u'way')
# (9, u'ways')
# (27, u'wb')
# (113, u'we')
# (15, u'weapons')
# (19, u'wear')
# (7, u'wearable')
# (9, u'wearing')
# (6, u'wears')
# (56, u'weather')
# (11, u'web')
# (51, u'wedding')
# (7, u'wednesday')
# (17, u'wednesdays')
# (75, u'week')
# (31, u'weekend')
# (23, u'weekly')
# (5, u'weeks')
# (7, u'weezer')
# (14, u'weigh')
# (28, u'weight')
# (36, u'weinstein')
# (104, u'weird')
# (10, u'weirdest')
# (12, u'welcome')
# (16, u'wellness')
# (14, u'wendover')
# (47, u'wendy')
# (7, u'wengie')
# (9, u'wes')
# (41, u'west')
# (6, u'westbrook')
# (7, u'wet')
# (18, u'whale')
# (304, u'what')
# (13, u'whatever')
# (14, u'whats')
# (19, u'wheel')
# (21, u'when')
# (15, u'where')
# (11, u'whhl')
# (7, u'whisper')
# (10, u'whistle')
# (144, u'white')
# (7, u'whitlock')
# (29, u'who')
# (11, u'whole')
# (55, u'why')
# (7, u'wi3')
# (15, u'widow')
# (20, u'wife')
# (12, u'wig')
# (57, u'wild')
# (8, u'wilderness')
# (6, u'wildfire')
# (9, u'wildflowers')
# (15, u'wildlife')
# (10, u'wildnerness')
# (170, u'will')
# (21, u'william')
# (68, u'williams')
# (13, u'willie')
# (78, u'wilson')
# (9, u'wilton')
# (26, u'win')
# (37, u'wind')
# (6, u'window')
# (12, u'wine')
# (21, u'winfrey')
# (10, u'wing')
# (47, u'wings')
# (18, u'winner')
# (7, u'winners')
# (7, u'winning')
# (5, u'winona')
# (7, u'winslet')
# (5, u'winston')
# (29, u'winter')
# (29, u'wired')
# (10, u'wireless')
# (12, u'wisdom')
# (6, u'wiseau')
# (32, u'wish')
# (6, u'witch')
# (352, u'with')
# (15, u'witherspoon')
# (19, u'without')
# (15, u'witney')
# (24, u'wizard')
# (20, u'wk')
# (5, u'wncn')
# (10, u'wolf')
# (5, u'wolfhard')
# (123, u'woman')
# (120, u'women')
# (6, u'won')
# (100, u'wonder')
# (5, u'wonders')
# (6, u'wonderstruck')
# (6, u'wonderwoman')
# (10, u'wood')
# (17, u'woods')
# (19, u'word')
# (64, u'work')
# (12, u'working')
# (9, u'workout')
# (310, u'world')
# (5, u'worldnews')
# (14, u'worlds')
# (7, u'worldwide')
# (8, u'worship')
# (40, u'worst')
# (67, u'worth')
# (16, u'would')
# (10, u'wouldn')
# (17, u'wow')
# (5, u'wrap')
# (11, u'wrestle')
# (10, u'wrestler')
# (27, u'wrestling')
# (15, u'wright')
# (10, u'writer')
# (14, u'writing')
# (29, u'wrong')
# (15, u'wu')
# (68, u'wwe')
# (35, u'wwhl')
# (11, u'wyatt')
# (9, u'xbox')
# (8, u'xgames')
# (8, u'xian')
# (64, u'xl')
# (52, u'xx')
# (9, u'xxxtentacion')
# (12, u'ya')
# (12, u'yachty')
# (50, u'year')
# (28, u'years')
# (5, u'yee')
# (55, u'yellow')
# (6, u'yes')
# (8, u'yiay')
# (46, u'yolanda')
# (138, u'york')
# (333, u'you')
# (84, u'young')
# (20, u'younger')
# (124, u'your')
# (5, u'yours')
# (40, u'yourself')
# (10, u'yous')
# (6, u'yousaf')
# (280, u'youtube')
# (10, u'youtubeblack')
# (32, u'youtuber')
# (27, u'youtubers')
# (6, u'yoyo')
# (9, u'ysl')
# (15, u'yt')
# (8, u'yulin')
# (5, u'yxm0uar')
# (48, u'zac')
# (12, u'zach')
# (7, u'zack')
# (5, u'zaga')
# (5, u'zane')
# (5, u'zara')
# (17, u'zayn')
# (30, u'zedd')
# (12, u'zelda')
# (11, u'zero')
# (5, u'ziggler')
# (7, u'zimmer')
# (5, u'zippo')
# (11, u'zoe')
# (11, u'zoella')
# (25, u'zombie')
# (5, u'zombies')
# (16, u'zoo')
# (6, u'zu')
# (5, u'\u03bd\u03c4\u03cc\u03bc\u03b9\u03bd\u03bf')
# (5, u'\u0434\u043e\u043c\u0438\u043d\u043e')
# (7, u'\u043a\u043e\u0442')
# (7, u'\u0441\u0430\u0439\u043c\u043e\u043d\u0430')
# (9, u'\u0645\u0635\u0627\u0631\u0639\u0647')
# (18, u'\u0921\u092c')
# (9, u'\u092a\u0930\u0938')
# (9, u'\u092a\u0939\u0932\u0935')
# (12, u'\u0930\u0939')
# (9, u'\u0935\u0938')
# (6, u'\u30bd\u30cb\u30fc')
# (5, u'\u30c9\u30df\u30ce')
# (6, u'\u4e2d\u56fd\u83dc')
# (5, u'\u9aa8\u724c')
# (5, u'\uac01\uc124\ud0d5')
# (11, u'\uac13\uc138\ube10')
# (5, u'\ub0a8\uc790')
# (5, u'\ub3c4\uc804')
# (5, u'\ub9e4\uc6b4')
# (5, u'\ubc18\uc751')
# (5, u'\ubc29\ud0c4')
# (5, u'\ubc29\ud0c4\uc18c\ub144\ub2e8')
# (8, u'\ube44\ud2b8\ubc15\uc2a4')
# (5, u'\ube45\ud788\ud2b8')
# (7, u'\uc601\uad6d')
# (7, u'\uc601\uad6d\ub0a8\uc790')
# (5, u'\uc601\uc0c1')
# (7, u'\uc62c\ub9ac')
# (5, u'\uc678\uad6d')
# (7, u'\uc678\uad6d\uc778')
# (5, u'\uc6c3\uae34')
# (5, u'\uc74c\uc2dd')
# (7, u'\uc870\uc26c')

# %% [markdown]
# Random forest with n_estimators = 18

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestRegressor

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestRegressor(n_estimators = 18) 

# Fit the forest to the training set, using the bag of words as 
# features and the views labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train["views"] )
# Out:
# Training the random forest...

# %%
# Get a bag of words for the test set, and convert to a numpy array
val_data_features = vectorizer.transform(clean_val_tags)
np.asarray(val_data_features)

# Use the random forest to make sentiment label predictions
print ("Predicting validation labels...\n")
result = forest.predict(val_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "views" column
output = pd.DataFrame( data={"video_id":val["video_id"], "views":val["views"], "views_preds":result} )
# Out:
# Predicting validation labels...

# %%
mse = np.mean((output['views'] - output['views_preds'])**2)

# %%
print (mse)
# Out:
# 2.81221310464e+12

# %% [markdown]
# Neural net

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(100,),max_iter=500)
neuralnets = mlp.fit(train_data_features, train["views"] )

# %%
result_n = neuralnets.predict(val_data_features)
output_n = pd.DataFrame( data={"video_id":val["video_id"], "views":val["views"], "views_preds":result_n} )

# %%
output_n
# Out:
#          video_id     views  views_preds
# 3633  xGuGjvIfof8    168468       294117
# 2554  b-znn2eQL08    380526       338457
# 6241  pSMCldcVGgA     16268        33098
# 6486  abeF5zQbQEM    393046       440886
# 1153  zcqZHYo7ONs    994795      1077745
# 6745  qEp3rwe3KmI     18419         6104
# 5361  D6oaRAgdslE    907723       681981
# 98    OudFElslbh4   1617247         6104
# 5832  Qg7YzqCRoZ0    186067       233063
# 3986  yAZwhN-WKGg     21837        12854
# 1284  Zr22PtGd1So    566996       209816
# 5433  evdxH50J3rs     77037       113025
# 3751  LaZQ_gj919U     79025        80610
# 4702  ENskipCo-eQ    597594       645693
# 5130  6l5P7jHUcjI    906398       488386
# 7951  JKZM1uTWBJw     53498        50181
# 4978  TMy0vJfKvzI    733187       708093
# 7494  O12Rt0JSDpA     20414        45488
# 6862  cCqS5X_zu-g    409924       385800
# 6317  Qg7YzqCRoZ0    226380       233063
# 6222  t8sgy0faXyg    359438       795286
# 6843  8d2Xw8BaoG8    640067       571044
# 5665  o6H0OPgg1qA    746089       578067
# 7092  K-zip2qToVY     16691        17542
# 7983  z2v_rL5C8C8    514052       451434
# 285   hQbeB0YXLhs   2511218      3304860
# 424   WYYvHb03Eog   4257519      3654879
# 4828  hhREiAarjVY   2370549      3271305
# 5802  Q0CbN8sfihY  23802798     26208268
# 3188  JU21shbaVBo    192301        64059
# ...           ...       ...          ...
# 5430  pqdaskhEa0I    369347         8031
# 2385  qLzIaAYFhNs     28143        27068
# 4553  j9UGpBZz7WU    265678       244753
# 844   nnTcCS07DKQ     83906        64374
# 6915  MpblOsqweUk    321548       206964
# 1949  HzIB6TC1Ghw    228803       217619
# 2982  k8T9SMqAqyc     94132        82858
# 5625  3JYl1XREYLE    320964       366650
# 4075  IUkNNDg18mY    845817       997541
# 4963  8Lv3tW7bWzU     23851        27175
# 1014  74zJ4scJzNs   1213185       888666
# 6178  o6H0OPgg1qA    855013       578067
# 2316  XF_ARz7jTUw   1684560      1785675
# 7881  Fpt3ImXIImY     14375         8162
# 5225  KGb5yAdkcFw   1099546       778207
# 5121  5CZAmbA4SfU    217960       269772
# 279   a7Sf_H2cFdM    947706       971242
# 6418  Tt-a61NG4XY    229896       292853
# 7539  xbBMVa2A68s    370320       356211
# 7477  dy5xLVx2NGY   1374054      1751165
# 2945  UdHopftQD3A    312169       157779
# 5465  0dWj2k4FMM8    734579       341798
# 2472  EHC6sYfF4cg   1540897      1624899
# 7453  WtF4TUxIOZk     20929        38367
# 5291  _4PLKxYZUPc    221006       177463
# 1774  T-IXvsQuogs    233903        70220
# 1757  RkBEEiG-wd4   1735326      1382327
# 7235  bvev1Bjx6oA   5438764      6511193
# 1237  _pc1kON-doU   4763854      5005454
# 1815  dUOUo02v4XE    323563         1731
#
# [1502 rows x 3 columns]

# %%
mse_n = np.mean((output_n['views'] - output_n['views_preds'])**2)

# %%
mse_n
# Out:
# 3356153597270.9614

# %% [markdown]
# Ensemble method: averaging

# %%
ensem = (output_n['views_preds']  + output['views_preds']) /2

# %%
mse_two = np.mean((output_n['views'] - ensem)**2)

# %%
mse_two
# Out:
# 2754967252219.076

# %% [markdown]
# ## Second attempt: using phrases in tags to predict 'views'
# Model: random forest + neuralnets

# %%
k = ','.join(clean_train_tags)
k = k.split(",")

# %%
from collections import Counter
import re
word_count = Counter(k)

# %%
top5000 = word_count.most_common(5000)
top5000
# Out:
# [('funny', 488),
#  ('comedy', 423),
#  ('2017', 202),
#  ('music', 198),
#  ('news', 184),
#  ('how to', 179),
#  ('trailer', 176),
#  ('makeup', 170),
#  ('food', 165),
#  ('celebrity', 165),
#  ('vlog', 163),
#  ('humor', 156),
#  ('tutorial', 154),
#  ('science', 153),
#  ('review', 150),
#  ('pop', 149),
#  ('beauty', 146),
#  ('interview', 145),
#  ('video', 137),
#  ('halloween', 129),
#  ('hollywood', 125),
#  ('diy', 120),
#  ('fashion', 108),
#  ('television', 104),
#  ('recipe', 100),
#  ('sketch', 99),
#  ('late night', 99),
#  ('live', 98),
#  ('comedian', 96),
#  ('movie', 93),
#  ('celebrities', 92),
#  ('film', 92),
#  ('entertainment', 90),
#  ('best', 89),
#  ('youtube', 88),
#  ('nbc', 87),
#  ('cooking', 86),
#  ('official', 86),
#  ('talk show', 86),
#  ('records', 84),
#  ('music video', 84),
#  ('funny video', 84),
#  ('donald trump', 83),
#  ('sports', 83),
#  ('buzzfeed', 81),
#  ('famous', 79),
#  ('new', 78),
#  ('apple', 77),
#  ('lifestyle', 76),
#  ('fun', 75),
#  ('nfl', 75),
#  ('official trailer', 73),
#  ('tv', 71),
#  ('new york', 71),
#  ('alternative', 70),
#  ('style', 70),
#  ('history', 69),
#  ('education', 68),
#  ('animation', 67),
#  ('technology', 66),
#  ('hilarious', 66),
#  ('iphone 8', 66),
#  ('travel', 65),
#  ('cute', 65),
#  ('unboxing', 64),
#  ('show', 63),
#  ('drama', 63),
#  ('makeup tutorial', 63),
#  ('family friendly', 62),
#  ('movies', 62),
#  ('iphone', 62),
#  ('football', 61),
#  ('kitchen', 60),
#  ('parody', 60),
#  ('jokes', 60),
#  ('politics', 60),
#  ('country', 59),
#  ('challenge', 59),
#  ('cosmetics', 59),
#  ('amazing', 59),
#  ('iphone x', 58),
#  ('clip', 58),
#  ('tech', 57),
#  ('trump', 57),
#  ('celeb', 56),
#  ('funny videos', 55),
#  ('google', 55),
#  ('cbs', 54),
#  ('love', 53),
#  ('family', 53),
#  ('joke', 53),
#  ('rihanna', 52),
#  ('netflix', 52),
#  ('fenty beauty', 52),
#  ('snl', 52),
#  ('fall', 52),
#  ('impressions', 51),
#  ('action', 51),
#  ('animals', 50),
#  ('haul', 50),
#  ('vlogging', 50),
#  ('kids', 49),
#  ('cheap', 49),
#  ('behind the scenes', 49),
#  ('highlights', 49),
#  ('stephen colbert', 49),
#  ('rap', 49),
#  ('chef', 48),
#  ('daily', 48),
#  ('cook', 48),
#  ('lol', 47),
#  ('girlfriend', 47),
#  ('laugh', 47),
#  ('host', 47),
#  ('song', 47),
#  ('easy', 46),
#  ('nba', 46),
#  ('vlogger', 46),
#  ('health', 46),
#  ('james corden', 45),
#  ('satire', 45),
#  ('crazy', 45),
#  ('disney', 45),
#  ('games', 45),
#  ('season', 45),
#  ('monologue', 44),
#  ('colbert', 44),
#  ('iphone 8 plus', 44),
#  ('highlight', 44),
#  ('dance', 43),
#  ('comedic', 43),
#  ('scary', 42),
#  ('fail', 42),
#  ('corden', 42),
#  ('las vegas shooting', 42),
#  ('test', 42),
#  ('late late show', 42),
#  ('hurricane', 42),
#  ('the late late show', 42),
#  ('', 41),
#  ('las vegas', 41),
#  ('animated', 41),
#  ('super', 41),
#  ('taste test', 41),
#  ('hip hop', 41),
#  ('actor', 40),
#  ('sketch comedy', 40),
#  ('talent', 40),
#  ('nbc tv', 40),
#  ('basketball', 39),
#  ('documentary', 39),
#  ('viral', 39),
#  ('game', 39),
#  ('dog', 39),
#  ('abc', 39),
#  ('kylie jenner', 39),
#  ('breaking news', 39),
#  ('alesso', 38),
#  ('boyfriend', 38),
#  ('stars', 38),
#  ('good', 38),
#  ('watch', 38),
#  ('adventure', 38),
#  ('vlogs', 37),
#  ('columbia', 37),
#  ('marshemllo', 37),
#  ('lelepons', 37),
#  ('how to make', 37),
#  ('season 12', 37),
#  ('marshmello', 37),
#  ('shotsstudios', 36),
#  ('sp:vl=en-us', 36),
#  ('today', 36),
#  ('pop culture', 36),
#  ('laurdiy', 36),
#  ('lgbt', 35),
#  ('trending', 35),
#  ('marvel', 35),
#  ('john green', 35),
#  ('do it yourself', 35),
#  ('new music', 35),
#  ('anwar', 35),
#  ('dancing with the stars', 34),
#  ('play', 34),
#  ('vs', 34),
#  ('hurricane irma', 34),
#  ('puerto rico', 34),
#  ('sp:ty=high', 34),
#  ('florida', 34),
#  ('kim kardashian', 34),
#  ('promo', 34),
#  ('hannahstocking', 33),
#  ('space', 33),
#  ('dwts', 33),
#  ('wonder woman', 33),
#  ('karaoke', 33),
#  ('female', 33),
#  ('cat', 33),
#  ('bbc', 33),
#  ('future', 32),
#  ('lyrics', 32),
#  ('girl', 32),
#  ('star wars', 32),
#  ('shots', 32),
#  ('cartoon', 32),
#  ('interviews', 32),
#  ('inannasarkis', 31),
#  ('official video', 31),
#  ('grwm', 31),
#  ('fenty', 31),
#  ('rudymancuso', 31),
#  ('inanna', 31),
#  ('puppy', 30),
#  ('gal gadot', 30),
#  ('hd', 30),
#  ('epic', 30),
#  ('hair', 30),
#  ('fitness', 30),
#  ('streaming', 30),
#  ('remix', 30),
#  ('get ready with me', 29),
#  ('japan', 29),
#  ('current events', 29),
#  ('how to cook', 29),
#  ('make', 29),
#  ('nyc', 29),
#  ('simple', 29),
#  ('expensive', 29),
#  ('guru', 29),
#  ('american football', 29),
#  ('fast food', 28),
#  ('gossip', 28),
#  ('spooky', 28),
#  ('kid friendly', 28),
#  ('clothes', 28),
#  ('talk', 28),
#  ('improv', 28),
#  ('jimmy', 28),
#  ('ellen', 28),
#  ('dad', 28),
#  ('woman', 28),
#  ('complex media', 27),
#  ('espn', 27),
#  ('rhett and link', 27),
#  ('dogs', 27),
#  ('irma', 27),
#  ('buzzfeedvideo', 27),
#  ('celebrity news', 27),
#  ('samsung', 27),
#  ('game of thrones', 27),
#  ('house', 27),
#  ('nashville', 27),
#  ('amazon', 27),
#  ('complex', 27),
#  ('liza koshy', 27),
#  ('how to bake', 27),
#  ('breaking', 27),
#  ('fast', 27),
#  ('nasa', 27),
#  ('cake', 27),
#  ('book', 27),
#  ('hot', 26),
#  ('foundation', 26),
#  ('original', 26),
#  ('food porn', 26),
#  ('clothing', 26),
#  ('entertainment news', 26),
#  ('culture', 26),
#  ('official music video', 26),
#  ('cupcakes', 26),
#  ('youtuber', 26),
#  ('blade runner', 26),
#  ('sp:st=football', 26),
#  ('shopping', 26),
#  ('defense', 26),
#  ('saturday night live', 26),
#  ('usa', 26),
#  ('musician', 26),
#  ('singer', 25),
#  ('episode', 25),
#  ('fox', 25),
#  ('worth it', 25),
#  ('internet', 25),
#  ('iisuperwomanii', 25),
#  ('autumn', 25),
#  ('baby', 25),
#  ('bartender', 25),
#  ('netflix original series', 25),
#  ('stand-up', 25),
#  ('jeffree star', 25),
#  ('iphone 8 review', 25),
#  ('drone', 25),
#  ('tips', 25),
#  ('therapy', 25),
#  ('gadgets', 25),
#  ('weird', 25),
#  ('reaction', 25),
#  ('new season', 25),
#  ('taylor swift', 25),
#  ('women', 25),
#  ('weather', 25),
#  ('halloween makeup tutorial', 24),
#  ('tricks', 24),
#  ('perfect', 24),
#  ('halloween makeup', 24),
#  ('capitol', 24),
#  ('the ellen show', 24),
#  ('skits', 24),
#  ('sport', 24),
#  ('transformation', 24),
#  ('plays', 24),
#  ('costume', 24),
#  ('father', 24),
#  ('smartphone', 24),
#  ('tour', 24),
#  ('ellen degeneres', 24),
#  ('island', 24),
#  ('cakes', 24),
#  ('recipes', 24),
#  ('got', 24),
#  ('model', 24),
#  ('nails', 24),
#  ('north korea', 24),
#  ('soccer', 24),
#  ('story', 24),
#  ('e! news', 24),
#  ('baking', 23),
#  ('ellen tickets', 23),
#  ('netflix series', 23),
#  ('world', 23),
#  ('guest', 23),
#  ('harry potter', 23),
#  ('blake shelton', 23),
#  ('ch originals', 23),
#  ('r&b', 23),
#  ('david letterman', 23),
#  ('recap', 23),
#  ('business', 23),
#  ('us news', 23),
#  ('iphone x review', 23),
#  ('interesting', 23),
#  ('party', 23),
#  ('ellen fans', 23),
#  ('carpool', 23),
#  ('nail tutorial', 23),
#  ('interscope', 23),
#  ('buttercream', 23),
#  ('advice', 23),
#  ('jacksfilms', 23),
#  ('degeneres', 23),
#  ('gay', 23),
#  ('bit', 23),
#  ('clips', 23),
#  ('collegehumor', 23),
#  ('touchdown', 23),
#  ('nail art', 23),
#  ('ellentube', 23),
#  ('storm', 23),
#  ('easy nail art', 23),
#  ('snl seth meyers', 22),
#  ('letterman', 22),
#  ('time', 22),
#  ('rca records label', 22),
#  ('ryan gosling', 22),
#  ('newspaper', 22),
#  ('huge', 22),
#  ('vox', 22),
#  ('miley cyrus', 22),
#  ('meyers', 22),
#  ('rick and morty', 22),
#  ('alex wassabi', 22),
#  ('death', 22),
#  ('comics', 22),
#  ('physics', 22),
#  (' lele pons', 22),
#  ('run', 22),
#  ('iphone 8 unboxing', 22),
#  ('home', 22),
#  ('skit', 22),
#  ('vogue', 22),
#  ('dancing', 22),
#  ('dessert', 22),
#  ('news satire', 22),
#  ('seth', 22),
#  ('top', 22),
#  ('harvey weinstein', 22),
#  ('catch', 22),
#  ('humour', 22),
#  ('food challenge', 22),
#  ('arnold', 22),
#  ('late night show', 22),
#  ('program', 22),
#  ('weekend update', 22),
#  ('collab', 22),
#  ('comedians', 21),
#  ('nature', 21),
#  ('chris young', 21),
#  ('first we feast', 21),
#  ('r29', 21),
#  ('offense', 21),
#  ('country music', 21),
#  ('experience', 21),
#  ('toy', 21),
#  ('r29 video', 21),
#  ('android', 21),
#  ('mythical morning', 21),
#  ('fenty beauty review', 21),
#  ('refinery 29', 21),
#  ('fruit', 21),
#  ('cook (profession)', 21),
#  ('the last jedi', 21),
#  ('celeb news', 21),
#  ('harrison ford', 21),
#  ('firstwefeast', 21),
#  ('mexico', 21),
#  ('empowerment', 21),
#  ('eating', 21),
#  ('hbo', 21),
#  ('refinery29', 21),
#  ('fwf', 21),
#  ('win', 21),
#  ('afc', 21),
#  ('gmm', 21),
#  ('shooting', 21),
#  ('rca records label nashville', 21),
#  ('burger', 21),
#  ('riverdale', 21),
#  ('chocolate', 21),
#  ('mtv', 21),
#  ('refinery29 video', 21),
#  ('design', 21),
#  ('top 10', 21),
#  ('nfc', 21),
#  ('seth meyers', 21),
#  ('good mythical morning', 21),
#  ('wild', 21),
#  ('superwoman', 21),
#  ('gaming', 20),
#  ('pixel 2 xl', 20),
#  ('late show', 20),
#  ('nyfw', 20),
#  ('congress', 20),
#  ('learn', 20),
#  ('apple iphone x', 20),
#  ('fire', 20),
#  ('lilly singh', 20),
#  ('sprint', 20),
#  ('us', 20),
#  ('books', 20),
#  ('the late show', 20),
#  ('08282016ntflxuscan', 20),
#  ('rookie', 20),
#  ('steven lim', 20),
#  ('gun', 20),
#  ('real', 20),
#  ('e! news now', 20),
#  ('make up', 20),
#  ('sp:li=nfl', 20),
#  ('viral video', 20),
#  ('anxiety', 20),
#  ('nail art tutorial', 20),
#  ('california', 20),
#  ('minutephysics', 20),
#  ('mom', 20),
#  ('aussie', 20),
#  ('videos', 20),
#  ('ellen audience', 20),
#  ('diy nails', 20),
#  ('td', 20),
#  ('earth', 20),
#  ('mua', 20),
#  ('safiya nygaard', 20),
#  ('environment', 20),
#  ('emmys', 20),
#  ('video games', 20),
#  ('cocktail', 20),
#  ('beauty tutorial', 20),
#  ('competition', 20),
#  ('diy nail art', 20),
#  ('atlantic records', 20),
#  ('craft beer', 20),
#  ('cheap vs expensive', 20),
#  ('summer', 19),
#  ('feature', 19),
#  ('$ vs $$$', 19),
#  ('kourtney kardashian', 19),
#  ('spider', 19),
#  ('buzzfeed andrew', 19),
#  ('gmm taste test', 19),
#  ('cover', 19),
#  ('p!nk', 19),
#  ('link', 19),
#  ('iphone x hands on', 19),
#  ('reality', 19),
#  ('television online', 19),
#  ('album', 19),
#  ('america', 19),
#  ('snl season 43', 19),
#  ('blade runner 2049', 19),
#  ('ben coleman', 19),
#  ('halloween tutorial', 19),
#  ('pennywise', 19),
#  ('engineering', 19),
#  ('rihanna makeup', 19),
#  ('puppies', 19),
#  ('nintendo', 19),
#  ('asian', 19),
#  ('lyric video', 19),
#  ('sj news', 19),
#  ('buzzfeed steven', 19),
#  ('sam smith', 19),
#  ('day', 19),
#  ('los angeles', 19),
#  ('buzzfeed worth it', 19),
#  ('tmz', 19),
#  ('london', 19),
#  ('alex', 19),
#  ('halloween 2017', 19),
#  ('raw', 19),
#  ('ocean', 19),
#  ('random', 19),
#  ('new york city', 19),
#  ('season 25', 19),
#  ('water', 19),
#  ('screenjunkies', 19),
#  ('logan', 19),
#  ('impersonation', 19),
#  ('hank green', 19),
#  ('art', 19),
#  ('outfit', 19),
#  ('screen junkies', 19),
#  ('nbc news', 18),
#  ('dna', 18),
#  ('apple iphone 8', 18),
#  ('lego', 18),
#  ('simon cowell', 18),
#  ('nikkie tutorials', 18),
#  ('weekly', 18),
#  ('rhett', 18),
#  ('psychology', 18),
#  ('relationship', 18),
#  ('keeping up with the kardashians', 18),
#  ('insane', 18),
#  ('watch movies', 18),
#  ('educational', 18),
#  ('for kids', 18),
#  ('tonight', 18),
#  ('audio', 18),
#  ('variety', 18),
#  ('relationships', 18),
#  ('luxury', 18),
#  ('good mythical morning will it', 18),
#  ('adorable', 18),
#  ('kitten', 18),
#  ('spicy food', 18),
#  ('mkbhd', 18),
#  ('pumpkin', 18),
#  ('concert', 18),
#  ('world news', 18),
#  ('cats', 18),
#  ('mcdonalds', 18),
#  ('the tonight show', 18),
#  ('jimmy fallon', 18),
#  ('singing', 18),
#  ('computer', 18),
#  ('twitter', 18),
#  ('justice league', 18),
#  ('demi lovato', 18),
#  ('explain', 18),
#  ('rock', 18),
#  ('money', 18),
#  ('toronto', 18),
#  ('costumes', 18),
#  ('vox.com', 18),
#  ('fallon monologue', 18),
#  ('superfruit', 18),
#  ('ios 11', 18),
#  ('sephora', 18),
#  ('red carpet', 18),
#  ('kardashian', 18),
#  ('school', 18),
#  ('blue', 18),
#  ('hip-hop', 18),
#  ('fallon stand-up', 18),
#  ('logan paul', 18),
#  ('actress', 18),
#  ('how-to', 18),
#  ('glam', 18),
#  ('rookies', 18),
#  ('inspirational', 18),
#  ('edm', 18),
#  ('simon', 18),
#  ('comedy sketches', 18),
#  ('top stories', 18),
#  ('rhett link', 18),
#  ('vanilla', 18),
#  ('record', 18),
#  ('first impressions', 17),
#  ('listen', 17),
#  ('pregnancy', 17),
#  ('russia', 17),
#  ('tested', 17),
#  ('beautiful', 17),
#  ('dress', 17),
#  ('plane', 17),
#  ('scott', 17),
#  ('grace', 17),
#  ('anything', 17),
#  ('try', 17),
#  ('producer', 17),
#  ('itsgrace', 17),
#  ('paul', 17),
#  ('s43', 17),
#  ('live stream', 17),
#  ('mitch', 17),
#  ('megan mullally', 17),
#  ('supercarlinbrothers', 17),
#  ('fox sports', 17),
#  ('anime', 17),
#  ('hannah', 17),
#  ('bravo', 17),
#  ('lizza', 17),
#  ('grassi', 17),
#  ('british', 17),
#  ('breakfast', 17),
#  ('lizzzavine', 17),
#  ('new song', 17),
#  ('help', 17),
#  ('gracehelbig', 17),
#  ('wow', 17),
#  ('fcute', 17),
#  ('facebook', 17),
#  ('movies online', 17),
#  ('lizzza', 17),
#  ('universal', 17),
#  ('else', 17),
#  ('rescue', 17),
#  ('iphone x vs', 17),
#  ('hoying', 17),
#  ('liza', 17),
#  ('helbig', 17),
#  ('unbox therapy', 17),
#  ('heres', 17),
#  ('man', 17),
#  ('obsessions', 17),
#  ('lizakoshy', 17),
#  ('beauty guru', 17),
#  ('everyone', 17),
#  ('dont', 17),
#  ('adam bianchi', 17),
#  ('madelaine petsch', 17),
#  ('google pixel 2', 17),
#  ('fashion week', 17),
#  ('gma', 17),
#  ('lizzzak', 17),
#  ('cracked', 17),
#  ('blogger', 17),
#  ('wednesdays', 17),
#  ('ed sheeran', 17),
#  ('dailygrace', 17),
#  ('healthy', 17),
#  ('stephen paddock', 17),
#  ('koshy', 17),
#  ('react', 17),
#  ('laurex', 17),
#  ('innovation', 17),
#  ('mean tweets', 17),
#  ('spoof', 17),
#  ('fox sports 1', 16),
#  ('china', 16),
#  ('manny mua', 16),
#  ('marbles', 16),
#  ('smosh', 16),
#  ('carlibel', 16),
#  ('cheryl blossom', 16),
#  ('jimmy kimmel live', 16),
#  ('couple', 16),
#  ('honest trailers', 16),
#  ('hot sauce', 16),
#  ('simply nailogical', 16),
#  ('jimmy kimmel', 16),
#  ('cameraguy', 16),
#  ('night', 16),
#  ('the voice', 16),
#  ('fight', 16),
#  ('step by step', 16),
#  ('james', 16),
#  ('scishow', 16),
#  ('hacks', 16),
#  ('jaclyn hill', 16),
#  ('mike boyd', 16),
#  ('mylifeaseva', 16),
#  ('amazon prime', 16),
#  ('amber scholl', 16),
#  ('hillary clinton', 16),
#  ('first impression', 16),
#  ('demo', 16),
#  ('clown', 16),
#  ('friends', 16),
#  ('lesbian', 16),
#  ('press conference', 16),
#  ('surprise', 16),
#  ('warner bros pictures', 16),
#  ('silly', 16),
#  ('basic', 16),
#  ('pastry', 16),
#  ('fs1', 16),
#  ('themed', 16),
#  ('cute cats', 16),
#  ('asmr', 16),
#  ('iphone x unboxing', 16),
#  ('eyes', 16),
#  ('channel', 16),
#  ('rihanna makeup line', 16),
#  ('cancer', 16),
#  ('spicy', 16),
#  ('family vlogs', 16),
#  ('compilation', 16),
#  ('photography', 16),
#  ('lele', 16),
#  ('kardashians', 16),
#  ('routine', 16),
#  ('eating challenge', 16),
#  ('like', 16),
#  ('happens', 16),
#  ('halloween costumes', 16),
#  ('buzzfeed adam', 16),
#  ('honest trailer', 16),
#  ('inspire', 16),
#  ('llc', 16),
#  ('cool', 16),
#  ('colin', 16),
#  ('wb pictures', 16),
#  ('blog', 16),
#  ('mental health', 16),
#  ('tasty', 16),
#  ('ted', 16),
#  ('fall makeup', 16),
#  ('the verge', 16),
#  ('teaser', 16),
#  ('drugstore makeup', 16),
#  ('learn quick', 16),
#  ('the infographics show', 16),
#  ('english', 16),
#  ('foodie', 15),
#  ('kylie cosmetics', 15),
#  ('petsch', 15),
#  ('australia', 15),
#  ('safiya and tyler', 15),
#  ('jennifer lawrence', 15),
#  ('icing', 15),
#  ('dji', 15),
#  ('sean evans', 15),
#  (' anwar jibawi', 15),
#  ('chicago', 15),
#  ('parents', 15),
#  ('too good at goodbyes', 15),
#  ('kane brown', 15),
#  ('magic', 15),
#  ('wassabi productions', 15),
#  ('korean', 15),
#  ('gymnastics', 15),
#  ('david dobrik', 15),
#  ('movie trailer', 15),
#  ('creepy', 15),
#  ('madelaine', 15),
#  ('kevin durant', 15),
#  ('blossom', 15),
#  ('q&a', 15),
#  ('cheryl', 15),
#  ('pixel 2', 15),
#  ('ryan', 15),
#  ('from scratch', 15),
#  ('making of', 15),
#  ('tmz2016fs11221', 15),
#  ('oprah winfrey', 15),
#  ('meat', 15),
#  ('royal', 15),
#  ('matpat', 15),
#  ('olympics', 15),
#  ('freestyle', 15),
#  ('reviews', 15),
#  ('first', 15),
#  ('performance', 15),
#  ('everyday', 15),
#  ('will & grace', 15),
#  ('single', 15),
#  ('philosophy', 15),
#  ('madelainepetsch', 15),
#  ('adam ruins everything', 15),
#  ('2d animation', 15),
#  ('cherylblossom', 15),
#  ('what if', 15),
#  ('kanye west', 15),
#  ('beyonce', 15),
#  ('hurricane maria', 15),
#  ('candy', 15),
#  ('andy cohen', 15),
#  ('katy perry', 15),
#  ('what what happens live', 15),
#  ('collaboration', 15),
#  ('slow motion', 15),
#  ('buzzfeed video', 15),
#  ('kuwtk', 15),
#  ('rclbeauty101', 14),
#  ('tomb raider', 14),
#  ('the new york times', 14),
#  ('rick and morty season 3', 14),
#  ('men', 14),
#  ('life', 14),
#  ('live video', 14),
#  ('awesome', 14),
#  ('jibawi', 14),
#  ('times video', 14),
#  ('wired', 14),
#  ('youtubers', 14),
#  ('super carlin brothers', 14),
#  ('health care', 14),
#  ('ti', 14),
#  ('full', 14),
#  ('high vs low', 14),
#  ('animal rescue', 14),
#  ('tofield', 14),
#  ('spinners', 14),
#  ('wildlife', 14),
#  ('charity', 14),
#  ('halloween costume', 14),
#  ('pizza', 14),
#  ('green', 14),
#  ('nigahiga', 14),
#  ('wired.com', 14),
#  ('kate mckinnon', 14),
#  ('kkw beauty', 14),
#  ('brothers', 14),
#  ('car', 14),
#  ('buzzfeedblue', 14),
#  ('half', 14),
#  ('celebrity interviews', 14),
#  ('fidget spinners', 14),
#  ('iphone 10', 14),
#  ('instagram', 14),
#  ('miranda sings', 14),
#  ('sugar stars', 14),
#  ('how to cake it', 14),
#  ('guide', 14),
#  ('cheap vs. expensive', 14),
#  ('ny times', 14),
#  ('friendly', 14),
#  ('products', 14),
#  ('ben carlin', 14),
#  ('pixel', 14),
#  ('sweets', 14),
#  ('j carlin', 14),
#  ('theinfographicsshow', 14),
#  ('howto', 14),
#  ('maverick', 14),
#  ('animal video', 14),
#  ('girls', 14),
#  ('yolanda gampp', 14),
#  ('pets', 14),
#  ('wwe', 14),
#  ('diet', 14),
#  ('earthquake', 14),
#  ('tech insider', 14),
#  ('nyt', 14),
#  ('ted ed', 14),
#  ('turtles all the way down', 14),
#  ('ted education', 14),
#  ('white house', 14),
#  ('ted-ed', 14),
#  ('eye', 14),
#  ('digital culture', 14),
#  ('mma', 14),
#  ('target', 14),
#  ('restaurant', 14),
#  ('unboxtherapy', 14),
#  ('ufc', 14),
#  ('camera', 14),
#  ('meet arnold', 14),
#  ('la', 14),
#  ('nytimes.com', 14),
#  ('tmz 2017', 14),
#  ('charles', 14),
#  ('reporting', 14),
#  ('ny', 14),
#  ('unbox', 14),
#  ('children', 14),
#  ('australian', 14),
#  ('iphone 8 vs', 14),
#  ('birthday', 14),
#  ('gun control', 14),
#  ('motion', 14),
#  ('white', 14),
#  ('ideas', 14),
#  ('youtube trending', 14),
#  ('andrew', 14),
#  ('the voice season 13', 14),
#  ('chocolate cake recipe', 14),
#  ('racism', 14),
#  ('taylor', 14),
#  ('emoji', 14),
#  ('pons', 14),
#  ('airplane', 14),
#  ('how to cake it by yolanda', 14),
#  ('store', 14),
#  ('the rock', 14),
#  ('wrestling', 14),
#  ('the dodo', 14),
#  ('jenna', 14),
#  ('whale', 14),
#  ('hop', 13),
#  ('colin kaepernick', 13),
#  ('(us)', 13),
#  ('the today show', 13),
#  ('adam ruins', 13),
#  ('dc comics', 13),
#  ('explained', 13),
#  ('music videos', 13),
#  ('people', 13),
#  ('today show interview', 13),
#  ('chit chat', 13),
#  ('fergie', 13),
#  ('alone', 13),
#  ('vote', 13),
#  ('chat show', 13),
#  ('morning routine', 13),
#  ('fame', 13),
#  ('kitty', 13),
#  ('mental floss', 13),
#  ('how to make vanilla cupcakes', 13),
#  ('film theory', 13),
#  ('thor', 13),
#  ('chocolate cupcakes', 13),
#  ('jonathan carlin', 13),
#  ('nick makrides', 13),
#  ('the gabbie show', 13),
#  ('prank', 13),
#  ('emmy', 13),
#  ('glam and g', 13),
#  ('cmt', 13),
#  ('graham norton', 13),
#  ('work', 13),
#  ('hank', 13),
#  ('ijustine', 13),
#  ('hand in hand', 13),
#  ('pastry design', 13),
#  ('screen junkies news', 13),
#  ('trick', 13),
#  ('gordon ramsay', 13),
#  ('ultimate fighting championship', 13),
#  ('comparison', 13),
#  ('american', 13),
#  ('family vlog', 13),
#  ('comic books', 13),
#  ('look', 13),
#  ('plvahqwmqn4m1uq5jitdkmnrxznwtug-dp', 13),
#  ('wwhl', 13),
#  ('screenjunkies news', 13),
#  ('hip', 13),
#  ('lookbook', 13),
#  ('management', 13),
#  ('humans', 13),
#  ('lose', 13),
#  ('watch what happens live', 13),
#  ('casey neistat', 13),
#  ('adultolescence', 13),
#  ('rights', 13),
#  ('how to pipe cupcakes', 13),
#  ('nevada', 13),
#  ('google phone', 13),
#  ('movie news', 13),
#  ('bravo andy', 13),
#  ('niall horan', 13),
#  ('frosting', 13),
#  ('verge', 13),
#  ('klg and hoda', 13),
#  ('stupid', 13),
#  ('bmg', 13),
#  ('bmw', 13),
#  ('ambush makeover', 13),
#  ('over the top recipes', 13),
#  ('mini bull terrier', 13),
#  ('how to make macarons', 13),
#  ('glam&g', 13),
#  ('andrew ilnyckyi', 13),
#  ('experiment', 13),
#  ('adam levine', 13),
#  ('vine', 13),
#  ('secret', 13),
#  ('big', 13),
#  ('mass shooting', 13),
#  ('easy cupcake recipes', 13),
#  ('sleep', 13),
#  ('the scran line', 13),
#  ('wassabi', 13),
#  ('preview', 13),
#  ('smile', 13),
#  ('iphone 2017', 13),
#  ('today show', 13),
#  ('kathie lee and hoda', 13),
#  ...]

# %%
lst = []
for value, count in top5000:
    lst.append(value)

# %%
freq_train = []
for word in lst:
    l = []
    for i in clean_train_tags:
        splits = i.split(",")
        if word in splits:
            l.append(1)
        else:
            l.append(0)
    l = np.asarray(l)
    freq_train.append(l)

# %%
freq__train_table = pd.DataFrame(freq_train)
freq__train_table = pd.DataFrame.transpose(freq__train_table)
freq__train_array = freq__train_table.values

# %% [markdown]
# Random Forest

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestRegressor

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestRegressor(n_estimators = 5) 

# Fit the forest to the training set, using the bag of words as 
# features and the views labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit(freq__train_array, train["views"] )
# Out:
# Training the random forest...

# %%
freq = []
for word in lst:
    l = []
    for i in clean_val_tags:
        splits = i.split(",")
        if word in splits:
            l.append(1)
        else:
            l.append(0)
    l = np.asarray(l)
    freq.append(l)
    
freq_array = np.asarray(freq)
freq_table = pd.DataFrame(freq)
freq_table = pd.DataFrame.transpose(freq_table)
freq_array = freq_table.values

# %%
result = forest.predict(freq_array)

# Copy the results to a pandas dataframe with an "id" column and
# a "views" column
output = pd.DataFrame( data={"video_id":val["video_id"], "views":val["views"], "views_preds":result} )

# %%
mse = np.mean((output['views'] - output['views_preds'])**2)

# %%
print (mse)
# Out:
# 3.09146239283e+12

# %% [markdown]
# Neural network

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(100,),max_iter=500)
neuralnets = mlp.fit(freq__train_array, train["views"] )

# %%
result_n = neuralnets.predict(freq_array)

output_n = pd.DataFrame( data={"video_id":val["video_id"], "views":val["views"], "views_preds":result} )

# %%
mse_n = np.mean((output_n['views'] - output_n['views_preds'])**2)

# %%
mse_n
# Out:
# 3195527762453.9126

# %% [markdown]
# Ensemble : averaging

# %%
ensem = (output_n['views_preds']  + output['views_preds']) /2

# %%
mse_two = np.mean((output_n['views'] - ensem)**2)

# %%
mse_two
# Out:
# 3017388949132.5747

# %% [markdown]
# Since the model using words in our first attempt has better performance on the validation data, we choose this model to make our prediction.

# %% [markdown]
# # Use the test data to evaluate the performance of the chosen model

# %%
test_data_features = vectorizer.transform(clean_test_tags)
np.asarray(test_data_features)


print ("Predicting test labels...\n")
result = forest.predict(test_data_features)
output = pd.DataFrame( data={"video_id":test["video_id"], "views":test["views"], "views_preds":result} )
result_n = neuralnets.predict(test_data_features)
output_n = pd.DataFrame( data={"video_id":test["video_id"], "views":test["views"], "views_preds":result_n} )

ensem = (output_n['views_preds']  + output['views_preds']) /2

mse_two = np.mean((output_n['views'] - ensem)**2)
mse_two
# Out:
# Predicting test labels...
# 6184319423547.551
